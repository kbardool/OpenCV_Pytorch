# %% [markdown]
# # <font style="color:blue">Binary Classification using a Perceptron</font>

# %% [markdown]
# We have seen the building blocks of a Neural Network. Before we start going into the details of neural networks, we will illustrate what a single neuron is capable of! Specifically, we will solve a Binary Classification problem ( with the same linearly separable data shown in the earlier lecture ) using a single Neuron.
#
# The insteresting part is that we will implement all the building blocks from scratch so that you understand all the nuts and bolts of a Neuron and Neural Networks(by extension).

# %% [markdown]
# ## <font style="color:rgb(8,133,37)">Problem statement</font>
#
# We have two sets of data points generated with different mean and variance. The task is to train a classifier which is able to distinguish between the two classes. In other words, We have to find a hyperplane that separates the two sets of data.
#
# We have chosen the two-dimensional data as shown below, so we have to learn a line that separates these two sets of points. We will see in this notebook that by training the perceptron, we are trying to learn the parameters of the network which is same as estimating the parameters of the line separating the classes (also known as the **decision boundary**)
#
# <img src="https://www.learnopencv.com/wp-content/uploads/2020/01/c3_w2_problem_statement.png" width=500>

# %% [markdown]
# # <font style="color:blue">1. Training Pipeline</font>
# Given below is the training pipeline which consists of the Neuron and the weight update loop using the gradients. We have already learnt about neurons, activation functions, gradients and gradient descent weight update process in the previous sections. It's now time to put them all together and train a Binary Classifier.
#
# <img src="https://www.learnopencv.com/wp-content/uploads/2020/01/c3_w2_single_neuron_train_arch.jpg" width=1000>
#
# Let us understand the above pipeline in more details

# %% [markdown]
# ## <font style="color:green">The Neuron</font>
# The first part is the **`Neuron`** itself. The neuron has the following architecture:
#
# 1. Two `inputs` : $X = [x_1, x_2]$
# 1. Two `weights` : $W = [w_1, w_2]$
# 1. A `bias` Term : $B = b$
# 1. A `summation` which performs a weighted addition of the inputs. **The weights are learnable parameters**. Let's call it z for the time-being.
#
# $$w_1x_1 + w_2x_2 + b = z(say)$$
#
# 5. A `sigmoid activation` function at the output of the neuron. Mathematically, it is given as
#
# $$
# \sigma(z) = \frac{1}{1 + e^{-z}} = \frac{1}{1 + e^{-(w_1x_1 + w_2x_2 + b)}} = y'(say)
# $$
#
# ## <font style="color:green">Loss Function</font>
# $y'$ gives the predicted output for a given input. Since this is the output of a sigmoid, it can also be thought of as a probability measure of class 1 or in other words, it gives the likelihood of class 1. We compare y' with the actual output ( also called thr ground_truth ) and compute a loss function. The loss function used for binary classification is the **`Binary Cross Entropy loss function`**. We will discuss about this in the next section. Mathematically, it is given as:
#
# $$
# J(y') = -y\log(y') - (1-y)\log(1-y')
# $$
#
# ## <font style="color:green">Backpropagation</font>
# The final part is the Weight update where we use **`Backpropagation`** to compute gradients and update the weights.
#
#
# **Compute Gradients**
#
# We need to compute the gradients of the loss function with respect to the weights and biases.
#
# $$
# \frac{\partial J}{\partial W}, \frac{\partial J}{\partial B}
# $$
#
# **Chain Rule**
#
# Since we cannot compute the gradients directly, we can use the chain rule described in the last section on Backpropagation. Applying chain rule, we get the following:
#
# \begin{align}
# \frac{\partial J}{\partial w_1} &= \frac{\partial J}{\partial y'}.\frac{\partial y'}{\partial z}. \frac{\partial z}{\partial w_1}  \\
# \frac{\partial J}{\partial w_2} &= \frac{\partial J}{\partial y'}.\frac{\partial y'}{\partial z}. \frac{\partial z}{\partial w_2}  \\
# \frac{\partial J}{\partial b} &= \frac{\partial J}{\partial y'}.\frac{\partial y'}{\partial z}. \frac{\partial z}{\partial b}  \\
# \end{align}
#
# **NOTE**: We can calculate the above derivatives separately and multiply them to get the required gradient.
#
# **Weight Update**
#
# The final step is to update the weights using the calculated gradients. This is done using the following equations.
#
# $$
# W \leftarrow W - \gamma \frac{\partial J}{\partial W}, \
# B \leftarrow B - \gamma \frac{\partial J}{\partial B}
# $$

# %%
from IPython.display import HTML
# from IPython.display import display, Image
display(HTML("<style>.container { width:98% !important; }</style>"))
# %load_ext autoreload  
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>.container { width:98% !important; }</style>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt  # one of the best graphics library for python
import matplotlib.animation as animation
plt.style.use('ggplot')

# %%
import torch
import numpy as np
import random

# %%
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# **Reproducibility first - let's fix all the random numbers generators to obtain reproducible results.**

# %%
seed = 3
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# # <font style="color:blue">2. Create Data points</font>
#
# We will create random data using a gaussian distribution. The data is similar to the one discussed in the lecture. This will be used for illustration

# %%
num_data_points = 500
class_zero_points = torch.empty(num_data_points, 2).normal_(mean=2,std=0.5)
class_one_points = torch.empty(num_data_points, 2).normal_(mean=4,std=0.7)

# %%
plt.scatter(class_zero_points[:,0], class_zero_points[:,1], s=8, color='b', label='Class:0')
plt.scatter(class_one_points[:,0], class_one_points[:,1], s=8, color='r', label='Class:1')
plt.legend()
plt.xlim([-1, 8])
plt.ylim([-1, 8])
plt.xlabel('x1')
plt.ylabel('x2')
# Out:
# (-1.0, 8.0)
# (-1.0, 8.0)
# Text(0.5, 0, 'x1')
# Text(0, 0.5, 'x2')

# %% [markdown]
# # <font style="color:blue">3. Prepare Data</font>
#
# We prepare the data so that it contains the data points from both classes.

# %%
label_zero = torch.zeros_like(class_zero_points[:,0], dtype=int)
label_one = torch.ones_like(class_one_points[:,0], dtype=int)

label = torch.cat([label_zero, label_one])
data_points = torch.cat([class_zero_points, class_one_points], dim=0)

print('Data points size: {}'.format(data_points.size()))
print('Label size: {}'.format(label.size()))
# Out:
# Data points size: torch.Size([1000, 2])
# Label size: torch.Size([1000])

# %% [markdown]
# # <font style="color:blue">4. Implementing the Perceptron</font>
# This is the neuron which is simply calculating the weighted sum of the inputs. It is given by:
#
# $$
# WX + B = w_1x_1 + w_2x_2 + b = z \text{  (let's)}
# $$
#
# Let's calculate the derivative of $z$ w.r.t the weights and bias.
#
# **Derivative of $WX + B$  w.r.t its input $W$ and $B$:**
#
# $$
# \begin{align}
# \frac{\partial z}{\partial w_1} &= x_1  \\
# \frac{\partial z}{\partial w_2} &= x_2  \\
# \frac{\partial z}{\partial b} &= 1
# \end{align}
# $$
#
# Let's define the perceptron and its derivative.

# %%
# Neuron: WX + B
def wx_plus_b(W, X, B):
    
    return torch.matmul(X, W) + B

# Derivative of WX + B w.r.t its input W and B
def grad_wx_plus_b(X):
    batch_size = X.size(0)
    g_w = X
    g_b = torch.ones(batch_size)
    
    return g_w, g_b

# %% [markdown]
# # <font style="color:blue">5. Why Sigmoid Activation?</font>
# The Sigmoid function is given by:
#
# $$
# y' = \sigma(z) = \frac{1}{1 + e^{-z}}
# $$
# Let's plot the curve of a sigmoid function and see

# %%
# Plot sigmoid
plt.rcParams["figure.figsize"] = (10, 6)
z = torch.linspace(-10, 10, 1000)
y = torch.sigmoid(z)

plt.figure
plt.plot(z, y, color='b')
plt.xlabel('z')
plt.ylabel('sigmoid(z)')
plt.title('Sigmoid Activation')
plt.show()
# Out:
# <function matplotlib.pyplot.figure(num: 'int | str | Figure | SubFigure | None' = None, figsize: 'ArrayLike | None' = None, dpi: 'float | None' = None, *, facecolor: 'ColorType | None' = None, edgecolor: 'ColorType | None' = None, frameon: 'bool' = True, FigureClass: 'type[Figure]' = <class 'matplotlib.figure.Figure'>, clear: 'bool' = False, **kwargs) -> 'Figure'>
# Text(0.5, 0, 'z')
# Text(0, 0.5, 'sigmoid(z)')
# Text(0.5, 1.0, 'Sigmoid Activation')

# %% [markdown]
# **We can observe the following points in `sigmoid` plot:**
#
# - $sigmoid(0) = 0.5$
# - $sigmoid(z) > 0.5$    $\text{  }\forall\text{ }z > 0$
# - $sigmoid(z) < 0.5$    $\text{  }\forall\text{ }z < 0$
#
# **We can use this property to derive the probability as follows:**
#
# - If $sigmoid(z) > 0.5$ then input belongs to the positive class or class `1`
# - If $sigmoid(z) < 0.5$ then input belongs to the negative class or class `0`
#
# The `sigmoid` output $y'$ may be thought of as probability that the data point belongs to class `1`. So, the probability that it belongs to class `0` will be $1-y'$.

# %% [markdown]
# ## <font style="color:rgb(8,133,37)">Implementing Sigmoid Activation</font>
# Let us implement the sigmoid activation and it's gradient function.
#
# **Sigmoid:**
#
# $$
# y' = \sigma(z) = \frac{1}{1 + e^{-z}}
# $$
#
# **Derivative of sigmoid w.r.t. its input.**
#
# $$
# \frac{\partial y'}{\partial z}  = \sigma(z)(1 - \sigma(z)) = y'(1-y')
# $$

# %%
# Sigmoid
def sigmoid(x):
    print(torch.sigmoid(x).shape,  torch.sigmoid(x).squeeze().shape)
    return torch.sigmoid(x).squeeze()

# Derivative of sigmoid w.r.t. its input.
def grad_sigmoid(x):
    
    return sigmoid(x) * (1 - sigmoid(x))

# %%
x = torch.tensor([1.0])
print(sigmoid(x))
# Out:
# torch.Size([1]) torch.Size([])
# tensor(0.7311)

# %% [markdown]
# # <font style="color:blue">6. Why Binary Cross-Entropy?</font>
# The Binary cross entropy is given by:
# $$
# J(y^{'}) = -y\log(y^{'}) - (1-y)\log(1-y{'})
# $$
#
# **Let's break down the equation since there are only two classes [0,1]:**
#
# \begin{equation}
# J(y^{'})=\left\{\begin{array}{cc} -\log(y^{'}) & y=1\\ -\log(1-y{'}) & y=0 \end{array} \right. \label{eq2}
# \end{equation}
#
# **Let's plot for class `1` and `0`.**
#
# For sigmoid activation case, input to our binary cross-entropy loss will lie between `0-to-1`.

# %%
# cross entropy plot y =1 
plt.rcParams["figure.figsize"] = (6, 6)
x = torch.linspace(0, 1, 1000)
y1 = -torch.log(x)
y0 = -torch.log(1-x)

plt.figure
plt.plot(x, y1, color='b', label="J(y') | y = 1")
plt.plot(x, y0, color='r', label="J(y') | y = 0")
plt.xlabel("y'")
plt.ylabel("J(y')")
plt.legend(loc='upper center')
plt.title('Binary Cross-Entropy')
plt.show()
# Out:
# <function matplotlib.pyplot.figure(num: 'int | str | Figure | SubFigure | None' = None, figsize: 'ArrayLike | None' = None, dpi: 'float | None' = None, *, facecolor: 'ColorType | None' = None, edgecolor: 'ColorType | None' = None, frameon: 'bool' = True, FigureClass: 'type[Figure]' = <class 'matplotlib.figure.Figure'>, clear: 'bool' = False, **kwargs) -> 'Figure'>
# Text(0.5, 0, "y'")
# Text(0, 0.5, "J(y')")
# Text(0.5, 1.0, 'Binary Cross-Entropy')

# %% [markdown]
# Let's say a data point belongs to class `1` <font style="color:blue">( Blue Curve )</font>. If the output of the network is close to `0`, then from the above diagram we can see that the loss will be very high ( The blue curve goes to infinity ). Conversely, the loss is `0` if the output of the network is `1`.
#
# The same logic goes for the <font style="color:red">red curve</font>.
#
# Thus, this loss function accurately captures the binary classification error - i.e. the error is high when the predicted output is different from the ground truth and vice-versa. Thus, it is the correct loss function for solving a binary classification problem.

# %% [markdown]
# ## <font style="color:rgb(8,133,37)">Implementing Binary Cross-Entropy</font>
# Now that we know why we are using Binary Cross Entropy loss, lets implement the loss and also its gradient function
#
# **Binary cross-entropy:**
# $$
# J(y') = -y\log(y') - (1-y)\log(1-y')
# $$
#
# **Derivative of binary cross-entropy w.r.t its input $y'$.**
# $$
# \frac{\partial J}{\partial y'} = -\frac{y}{y'} + \frac{1-y}{1-y'}
# $$

# %%
# Binary cross-entropy
def bce_loss(sigmoid_pred, g_truth):
    loss = - (1 - g_truth)* torch.log(1 - sigmoid_pred) - g_truth * torch.log(sigmoid_pred)
    return loss

# Derivative of binary cross-entropy w.r.t its input.
def grad_bce_loss(sigmoid_pred, g_truth):
    return - (g_truth * (1 / sigmoid_pred)) + ((1 - g_truth) * (1 / (1 - sigmoid_pred)))

# %% [markdown]
# ## <font style="color:blue">7. Graph Implementation</font>
# Next, We will implement the network graph, forward pass and backward pass. **We find the gradients of the parameters $w_1$, $w_2$ and $b$, using the chain rule:** Thus, we compute the gradients for each node and multiply them to get the final gradients of the loss function with respect to the weights.
#
# \begin{align}
# \frac{\partial J}{\partial w_1} &= \frac{\partial J}{\partial y^{'}}.\frac{\partial y^{'}}{\partial z}. \frac{\partial z}{\partial w_1}  \\
# \frac{\partial J}{\partial w_2} &= \frac{\partial J}{\partial y^{'}}.\frac{\partial y^{'}}{\partial z}. \frac{\partial z}{\partial w_2}  \\
# \frac{\partial J}{\partial b} &= \frac{\partial J}{\partial y^{'}}.\frac{\partial y^{'}}{\partial z}. \frac{\partial z}{\partial b}  \\
# \end{align}

# %%
class BinaryClassifierGraph:
    def __init__(self):
        """
        It is initializing the variable that will be updated in `forward` and `loss` function. 
        Storing these values will be used in `backward` function to get the gradient.
        """
        
        # default gardient is zero
        self.w0_grad = 0
        self.w1_grad = 0
        self.b_grad = 0
        
        self.x_in = None
        self.wx_plus_b_out = None
        self.sigmoid_out = None
        
        self.bce_loss = None
        
        self.grad_bce_loss = None
        
        self.g_truth = None
        
    def forward(self, w, x, b):
        # updated input value, it will be used in backward pass
        self.x_in = x
        self.b_in = b
        self.w_in = w
        
        # Intermediate node with the weighted sum
        self.wx_plus_b_out = wx_plus_b(w, x, b)
        
        # Output node after applying activation function
        self.sigmoid_out = sigmoid(self.wx_plus_b_out)
            
        return self.sigmoid_out
    
    def loss(self, g_truth):
        
        self.g_truth = g_truth
        
        # Compute the binary cross entropy loss
        self.bce_loss = bce_loss(self.sigmoid_out, g_truth)
        return self.bce_loss.mean()
    
    def backward(self):
        # Compute the gradients of Loss w.r.t neuron output (y')
        d_bce_loss = grad_bce_loss(self.sigmoid_out, self.g_truth)
        
        # Compute the gradients of neuron output(y') w.r.t weighted sum(z)
        d_sigmoid = grad_sigmoid(self.wx_plus_b_out)
        
        # Compute the gradients of weighted sum(z) w.r.t weights and bias
        d_w, d_b = grad_wx_plus_b(self.x_in)
        
        # Using chain rule to find overall gradient of Loss w.r.t weights and bias
        self.w0_grad = d_bce_loss * d_sigmoid * d_w[:,0]
        self.w1_grad = d_bce_loss * d_sigmoid * d_w[:,1]
        self.b_grad = d_bce_loss * d_sigmoid * d_b
        
        return
    
    def gradients(self):
        
        w_grad = torch.tensor([[self.w0_grad.mean()], [self.w1_grad.mean()]])
        b_grad = torch.tensor([self.b_grad.mean()])
        
        return w_grad, b_grad

# %% [markdown]
# ## <font style="color:blue">8. Update Parameters</font>
#
# This is the gradient descent update step which we are already familiar with from previous week! Just to recap, we take the gradients and update the weights and biases. We use a scaling factor called the **Learning rate**.

# %%
def gradient_descent_update(w, b, dw, db, lr):
    w = w - lr * dw
    b = b - lr * db
    
    return w, b

# %% [markdown]
# ## <font style="color:blue">9. Training Loop</font>
#
# Training loop is running for the given number of epochs where we do the following:
#
# 1. Divide the data into batches
# 1. For each batch, we compute the activations using the `forward` pass.
# 1. Compute the loss using Binary Cross Entropy
# 1. Compute the gradients using the backward function.
# 1. Finally, update gradient using `gradient_descent_update` function.
#
# We keep track of the loss for each batch.

# %%
import time
def train(w, b, data_points, label, epochs=100, lr=0.01, batch_size=10):
    
    bc = BinaryClassifierGraph()
    
    # for storing loss of each batch
    avg_train_loss = np.array([])
    
    updated_parms = []
    for epoch in range(epochs):
        
        # for storing loss of each batch in current epoch
        avg_loss = np.array([])
        
        num_baches = int(len(label)/batch_size)
        
        # Shuffle data and label
        shuffled_index = random.sample(range(len(label)), len(label))  
        s_data_points = data_points[shuffled_index]
        s_label = label[shuffled_index]
        
        print('\nEpoch: {}'.format(epoch+1))
        
        for batch_idx in range(num_baches):
            # get training data in batch
            start_index = batch_idx * batch_size
            end_index = (batch_idx + 1) * batch_size
            data = s_data_points[start_index:end_index]
            g_truth = s_label[start_index:end_index]
            
            # forward pass
            bc.forward(w, data, b)
            
            # Find loss
            loss = bc.loss(g_truth)
            
            # Backward will find gradient using chain rule 
            bc.backward()
            
            # Get gradients after they are updated using the backward function
            grad_w, grad_b = bc.gradients()
            
            # Update parameters using gradient descent
            w, b = gradient_descent_update(w, b, grad_w, grad_b, lr)
                
            # to show training results
            avg_loss = np.append(avg_loss, [loss])
            avg_train_loss = np.append(avg_train_loss, [loss])
            time.sleep(0.001)
            print("\rBatch: {0}/{1} | Avg Batch Loss: {2:.3} | Batch Loss: {3:.3} | Avg Train Loss:{4:.3}".
                  format(batch_idx+1, num_baches, avg_loss.mean(), loss.item(), avg_train_loss.mean()), end="")
    
        # storing parameters to show decision boundary animition
        updated_parms.append((w.data[0][0].clone(), w.data[1][0].clone(), b.data[0].clone()))
            
    return w, b, avg_train_loss, updated_parms

# %% [markdown]
# # <font style="color:blue">10. Start Training</font>
#
# We initialize the parameters with random weights and start training

# %%
input_size = 2
w = torch.randn(input_size, 1)
b = torch.zeros(1)

w, b, avg_train_loss, updated_parms= train(w, b, data_points, label)
print('\nw:\n{}'.format(w))
print('\nb:\n{}'.format(b))
# Out:
# Epoch: 1
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 1/100 | Avg Batch Loss: 2.53 | Batch Loss: 2.53 | Avg Train Loss:2.53torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 2/100 | Avg Batch Loss: 2.16 | Batch Loss: 1.78 | Avg Train Loss:2.16torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 3/100 | Avg Batch Loss: 2.32 | Batch Loss: 2.65 | Avg Train Loss:2.32torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 4/100 | Avg Batch Loss: 2.31 | Batch Loss: 2.25 | Avg Train Loss:2.31torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 5/100 | Avg Batch Loss: 2.25 | Batch Loss: 2.02 | Avg Train Loss:2.25torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 6/100 | Avg Batch Loss: 2.21 | Batch Loss: 2.01 | Avg Train Loss:2.21torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 7/100 | Avg Batch Loss: 2.07 | Batch Loss: 1.21 | Avg Train Loss:2.07torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 8/100 | Avg Batch Loss: 2.06 | Batch Loss: 2.0 | Avg Train Loss:2.06torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 9/100 | Avg Batch Loss: 2.05 | Batch Loss: 2.02 | Avg Train Loss:2.05torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 10/100 | Avg Batch Loss: 2.05 | Batch Loss: 1.97 | Avg Train Loss:2.05torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 11/100 | Avg Batch Loss: 2.03 | Batch Loss: 1.84 | Avg Train Loss:2.03torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 12/100 | Avg Batch Loss: 1.95 | Batch Loss: 1.14 | Avg Train Loss:1.95torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 13/100 | Avg Batch Loss: 1.87 | Batch Loss: 0.903 | Avg Train Loss:1.87torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 14/100 | Avg Batch Loss: 1.83 | Batch Loss: 1.26 | Avg Train Loss:1.83torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 15/100 | Avg Batch Loss: 1.82 | Batch Loss: 1.72 | Avg Train Loss:1.82torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 16/100 | Avg Batch Loss: 1.77 | Batch Loss: 0.936 | Avg Train Loss:1.77torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 17/100 | Avg Batch Loss: 1.71 | Batch Loss: 0.809 | Avg Train Loss:1.71torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 18/100 | Avg Batch Loss: 1.71 | Batch Loss: 1.79 | Avg Train Loss:1.71torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 19/100 | Avg Batch Loss: 1.69 | Batch Loss: 1.32 | Avg Train Loss:1.69torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 20/100 | Avg Batch Loss: 1.69 | Batch Loss: 1.72 | Avg Train Loss:1.69torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 21/100 | Avg Batch Loss: 1.66 | Batch Loss: 1.0 | Avg Train Loss:1.66torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 22/100 | Avg Batch Loss: 1.64 | Batch Loss: 1.27 | Avg Train Loss:1.64torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 23/100 | Avg Batch Loss: 1.61 | Batch Loss: 0.973 | Avg Train Loss:1.61torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 24/100 | Avg Batch Loss: 1.59 | Batch Loss: 1.13 | Avg Train Loss:1.59torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 25/100 | Avg Batch Loss: 1.58 | Batch Loss: 1.16 | Avg Train Loss:1.58torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 26/100 | Avg Batch Loss: 1.54 | Batch Loss: 0.72 | Avg Train Loss:1.54torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 27/100 | Avg Batch Loss: 1.52 | Batch Loss: 0.977 | Avg Train Loss:1.52torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 28/100 | Avg Batch Loss: 1.5 | Batch Loss: 0.885 | Avg Train Loss:1.5torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 29/100 | Avg Batch Loss: 1.49 | Batch Loss: 1.31 | Avg Train Loss:1.49torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 30/100 | Avg Batch Loss: 1.47 | Batch Loss: 0.757 | Avg Train Loss:1.47torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 31/100 | Avg Batch Loss: 1.44 | Batch Loss: 0.688 | Avg Train Loss:1.44torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 32/100 | Avg Batch Loss: 1.43 | Batch Loss: 0.965 | Avg Train Loss:1.43torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 33/100 | Avg Batch Loss: 1.4 | Batch Loss: 0.627 | Avg Train Loss:1.4torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 34/100 | Avg Batch Loss: 1.39 | Batch Loss: 0.766 | Avg Train Loss:1.39torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 35/100 | Avg Batch Loss: 1.37 | Batch Loss: 0.731 | Avg Train Loss:1.37torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 36/100 | Avg Batch Loss: 1.35 | Batch Loss: 0.659 | Avg Train Loss:1.35torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 37/100 | Avg Batch Loss: 1.33 | Batch Loss: 0.761 | Avg Train Loss:1.33torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 38/100 | Avg Batch Loss: 1.31 | Batch Loss: 0.504 | Avg Train Loss:1.31torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 39/100 | Avg Batch Loss: 1.3 | Batch Loss: 0.912 | Avg Train Loss:1.3torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 40/100 | Avg Batch Loss: 1.29 | Batch Loss: 0.868 | Avg Train Loss:1.29torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 41/100 | Avg Batch Loss: 1.28 | Batch Loss: 0.834 | Avg Train Loss:1.28torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 42/100 | Avg Batch Loss: 1.27 | Batch Loss: 0.925 | Avg Train Loss:1.27torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 43/100 | Avg Batch Loss: 1.26 | Batch Loss: 0.932 | Avg Train Loss:1.26torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 44/100 | Avg Batch Loss: 1.25 | Batch Loss: 0.858 | Avg Train Loss:1.25torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 45/100 | Avg Batch Loss: 1.24 | Batch Loss: 0.747 | Avg Train Loss:1.24torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 46/100 | Avg Batch Loss: 1.23 | Batch Loss: 0.632 | Avg Train Loss:1.23torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 47/100 | Avg Batch Loss: 1.22 | Batch Loss: 0.815 | Avg Train Loss:1.22torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 48/100 | Avg Batch Loss: 1.21 | Batch Loss: 0.752 | Avg Train Loss:1.21torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 49/100 | Avg Batch Loss: 1.2 | Batch Loss: 0.893 | Avg Train Loss:1.2torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 50/100 | Avg Batch Loss: 1.19 | Batch Loss: 0.635 | Avg Train Loss:1.19torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 51/100 | Avg Batch Loss: 1.18 | Batch Loss: 0.59 | Avg Train Loss:1.18torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 52/100 | Avg Batch Loss: 1.17 | Batch Loss: 0.571 | Avg Train Loss:1.17torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 53/100 | Avg Batch Loss: 1.16 | Batch Loss: 0.567 | Avg Train Loss:1.16torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 54/100 | Avg Batch Loss: 1.15 | Batch Loss: 0.756 | Avg Train Loss:1.15torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 55/100 | Avg Batch Loss: 1.14 | Batch Loss: 0.636 | Avg Train Loss:1.14torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 56/100 | Avg Batch Loss: 1.13 | Batch Loss: 0.64 | Avg Train Loss:1.13torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 57/100 | Avg Batch Loss: 1.12 | Batch Loss: 0.646 | Avg Train Loss:1.12torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 58/100 | Avg Batch Loss: 1.11 | Batch Loss: 0.636 | Avg Train Loss:1.11torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 59/100 | Avg Batch Loss: 1.11 | Batch Loss: 0.725 | Avg Train Loss:1.11torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 60/100 | Avg Batch Loss: 1.1 | Batch Loss: 0.558 | Avg Train Loss:1.1torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 61/100 | Avg Batch Loss: 1.09 | Batch Loss: 0.701 | Avg Train Loss:1.09torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 62/100 | Avg Batch Loss: 1.09 | Batch Loss: 0.753 | Avg Train Loss:1.09torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 63/100 | Avg Batch Loss: 1.08 | Batch Loss: 0.541 | Avg Train Loss:1.08torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 64/100 | Avg Batch Loss: 1.07 | Batch Loss: 0.745 | Avg Train Loss:1.07torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 65/100 | Avg Batch Loss: 1.07 | Batch Loss: 0.738 | Avg Train Loss:1.07torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 66/100 | Avg Batch Loss: 1.06 | Batch Loss: 0.584 | Avg Train Loss:1.06torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 67/100 | Avg Batch Loss: 1.06 | Batch Loss: 0.896 | Avg Train Loss:1.06torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 68/100 | Avg Batch Loss: 1.05 | Batch Loss: 0.549 | Avg Train Loss:1.05torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 69/100 | Avg Batch Loss: 1.05 | Batch Loss: 0.829 | Avg Train Loss:1.05torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 70/100 | Avg Batch Loss: 1.05 | Batch Loss: 1.03 | Avg Train Loss:1.05torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 71/100 | Avg Batch Loss: 1.04 | Batch Loss: 0.692 | Avg Train Loss:1.04torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 72/100 | Avg Batch Loss: 1.04 | Batch Loss: 0.687 | Avg Train Loss:1.04torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 73/100 | Avg Batch Loss: 1.03 | Batch Loss: 0.617 | Avg Train Loss:1.03torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 74/100 | Avg Batch Loss: 1.03 | Batch Loss: 0.68 | Avg Train Loss:1.03torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 75/100 | Avg Batch Loss: 1.02 | Batch Loss: 0.699 | Avg Train Loss:1.02torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 76/100 | Avg Batch Loss: 1.02 | Batch Loss: 0.759 | Avg Train Loss:1.02torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 77/100 | Avg Batch Loss: 1.02 | Batch Loss: 0.87 | Avg Train Loss:1.02torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 78/100 | Avg Batch Loss: 1.02 | Batch Loss: 1.02 | Avg Train Loss:1.02torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 79/100 | Avg Batch Loss: 1.01 | Batch Loss: 0.792 | Avg Train Loss:1.01torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 80/100 | Avg Batch Loss: 1.01 | Batch Loss: 0.66 | Avg Train Loss:1.01torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 81/100 | Avg Batch Loss: 1.01 | Batch Loss: 0.75 | Avg Train Loss:1.01torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 82/100 | Avg Batch Loss: 1.0 | Batch Loss: 0.822 | Avg Train Loss:1.0torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 83/100 | Avg Batch Loss: 1.0 | Batch Loss: 0.701 | Avg Train Loss:1.0torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 84/100 | Avg Batch Loss: 0.998 | Batch Loss: 0.849 | Avg Train Loss:0.998torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 85/100 | Avg Batch Loss: 0.996 | Batch Loss: 0.8 | Avg Train Loss:0.996torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 86/100 | Avg Batch Loss: 0.993 | Batch Loss: 0.775 | Avg Train Loss:0.993torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 87/100 | Avg Batch Loss: 0.99 | Batch Loss: 0.705 | Avg Train Loss:0.99torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 88/100 | Avg Batch Loss: 0.987 | Batch Loss: 0.677 | Avg Train Loss:0.987torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 89/100 | Avg Batch Loss: 0.983 | Batch Loss: 0.694 | Avg Train Loss:0.983torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 90/100 | Avg Batch Loss: 0.98 | Batch Loss: 0.715 | Avg Train Loss:0.98torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 91/100 | Avg Batch Loss: 0.979 | Batch Loss: 0.837 | Avg Train Loss:0.979torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 92/100 | Avg Batch Loss: 0.976 | Batch Loss: 0.692 | Avg Train Loss:0.976torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 93/100 | Avg Batch Loss: 0.973 | Batch Loss: 0.706 | Avg Train Loss:0.973torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 94/100 | Avg Batch Loss: 0.973 | Batch Loss: 0.984 | Avg Train Loss:0.973torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 95/100 | Avg Batch Loss: 0.969 | Batch Loss: 0.645 | Avg Train Loss:0.969torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 96/100 | Avg Batch Loss: 0.965 | Batch Loss: 0.569 | Avg Train Loss:0.965torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 97/100 | Avg Batch Loss: 0.962 | Batch Loss: 0.656 | Avg Train Loss:0.962torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 98/100 | Avg Batch Loss: 0.96 | Batch Loss: 0.788 | Avg Train Loss:0.96torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 99/100 | Avg Batch Loss: 0.959 | Batch Loss: 0.8 | Avg Train Loss:0.959torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 100/100 | Avg Batch Loss: 0.955 | Batch Loss: 0.578 | Avg Train Loss:0.955
# Epoch: 2
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 1/100 | Avg Batch Loss: 0.78 | Batch Loss: 0.78 | Avg Train Loss:0.953torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 2/100 | Avg Batch Loss: 0.771 | Batch Loss: 0.763 | Avg Train Loss:0.951torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 3/100 | Avg Batch Loss: 0.82 | Batch Loss: 0.917 | Avg Train Loss:0.951torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 4/100 | Avg Batch Loss: 0.819 | Batch Loss: 0.817 | Avg Train Loss:0.95torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 5/100 | Avg Batch Loss: 0.817 | Batch Loss: 0.807 | Avg Train Loss:0.948torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 6/100 | Avg Batch Loss: 0.767 | Batch Loss: 0.521 | Avg Train Loss:0.944torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 7/100 | Avg Batch Loss: 0.751 | Batch Loss: 0.653 | Avg Train Loss:0.942torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 8/100 | Avg Batch Loss: 0.74 | Batch Loss: 0.659 | Avg Train Loss:0.939torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 9/100 | Avg Batch Loss: 0.727 | Batch Loss: 0.627 | Avg Train Loss:0.936torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 10/100 | Avg Batch Loss: 0.731 | Batch Loss: 0.765 | Avg Train Loss:0.934torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 11/100 | Avg Batch Loss: 0.724 | Batch Loss: 0.66 | Avg Train Loss:0.932torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 12/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.628 | Avg Train Loss:0.929torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 13/100 | Avg Batch Loss: 0.738 | Batch Loss: 1.0 | Avg Train Loss:0.93torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 14/100 | Avg Batch Loss: 0.745 | Batch Loss: 0.835 | Avg Train Loss:0.929torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 15/100 | Avg Batch Loss: 0.753 | Batch Loss: 0.861 | Avg Train Loss:0.929torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 16/100 | Avg Batch Loss: 0.754 | Batch Loss: 0.766 | Avg Train Loss:0.927torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 17/100 | Avg Batch Loss: 0.755 | Batch Loss: 0.78 | Avg Train Loss:0.926torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 18/100 | Avg Batch Loss: 0.74 | Batch Loss: 0.485 | Avg Train Loss:0.922torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 19/100 | Avg Batch Loss: 0.73 | Batch Loss: 0.54 | Avg Train Loss:0.919torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 20/100 | Avg Batch Loss: 0.73 | Batch Loss: 0.728 | Avg Train Loss:0.917torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 21/100 | Avg Batch Loss: 0.731 | Batch Loss: 0.766 | Avg Train Loss:0.916torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 22/100 | Avg Batch Loss: 0.731 | Batch Loss: 0.722 | Avg Train Loss:0.914torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 23/100 | Avg Batch Loss: 0.729 | Batch Loss: 0.691 | Avg Train Loss:0.913torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 24/100 | Avg Batch Loss: 0.737 | Batch Loss: 0.928 | Avg Train Loss:0.913torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 25/100 | Avg Batch Loss: 0.737 | Batch Loss: 0.732 | Avg Train Loss:0.911torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 26/100 | Avg Batch Loss: 0.735 | Batch Loss: 0.682 | Avg Train Loss:0.909torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 27/100 | Avg Batch Loss: 0.734 | Batch Loss: 0.706 | Avg Train Loss:0.908torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 28/100 | Avg Batch Loss: 0.727 | Batch Loss: 0.544 | Avg Train Loss:0.905torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 29/100 | Avg Batch Loss: 0.73 | Batch Loss: 0.798 | Avg Train Loss:0.904torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 30/100 | Avg Batch Loss: 0.725 | Batch Loss: 0.581 | Avg Train Loss:0.902torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 31/100 | Avg Batch Loss: 0.728 | Batch Loss: 0.817 | Avg Train Loss:0.901torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 32/100 | Avg Batch Loss: 0.721 | Batch Loss: 0.528 | Avg Train Loss:0.898torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 33/100 | Avg Batch Loss: 0.723 | Batch Loss: 0.774 | Avg Train Loss:0.897torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 34/100 | Avg Batch Loss: 0.724 | Batch Loss: 0.758 | Avg Train Loss:0.896torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 35/100 | Avg Batch Loss: 0.726 | Batch Loss: 0.803 | Avg Train Loss:0.896torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 36/100 | Avg Batch Loss: 0.724 | Batch Loss: 0.66 | Avg Train Loss:0.894torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 37/100 | Avg Batch Loss: 0.724 | Batch Loss: 0.723 | Avg Train Loss:0.893torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 38/100 | Avg Batch Loss: 0.724 | Batch Loss: 0.706 | Avg Train Loss:0.891torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 39/100 | Avg Batch Loss: 0.725 | Batch Loss: 0.754 | Avg Train Loss:0.89torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 40/100 | Avg Batch Loss: 0.725 | Batch Loss: 0.724 | Avg Train Loss:0.889torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 41/100 | Avg Batch Loss: 0.727 | Batch Loss: 0.825 | Avg Train Loss:0.889torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 42/100 | Avg Batch Loss: 0.721 | Batch Loss: 0.478 | Avg Train Loss:0.886torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 43/100 | Avg Batch Loss: 0.72 | Batch Loss: 0.681 | Avg Train Loss:0.884torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 44/100 | Avg Batch Loss: 0.72 | Batch Loss: 0.73 | Avg Train Loss:0.883torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 45/100 | Avg Batch Loss: 0.722 | Batch Loss: 0.783 | Avg Train Loss:0.883torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 46/100 | Avg Batch Loss: 0.722 | Batch Loss: 0.727 | Avg Train Loss:0.881torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 47/100 | Avg Batch Loss: 0.72 | Batch Loss: 0.652 | Avg Train Loss:0.88torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 48/100 | Avg Batch Loss: 0.718 | Batch Loss: 0.598 | Avg Train Loss:0.878torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 49/100 | Avg Batch Loss: 0.72 | Batch Loss: 0.806 | Avg Train Loss:0.878torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 50/100 | Avg Batch Loss: 0.723 | Batch Loss: 0.907 | Avg Train Loss:0.878torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 51/100 | Avg Batch Loss: 0.72 | Batch Loss: 0.526 | Avg Train Loss:0.875torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 52/100 | Avg Batch Loss: 0.717 | Batch Loss: 0.597 | Avg Train Loss:0.874torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 53/100 | Avg Batch Loss: 0.718 | Batch Loss: 0.774 | Avg Train Loss:0.873torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 54/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.611 | Avg Train Loss:0.871torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 55/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.695 | Avg Train Loss:0.87torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 56/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.721 | Avg Train Loss:0.869torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 57/100 | Avg Batch Loss: 0.717 | Batch Loss: 0.758 | Avg Train Loss:0.868torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 58/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.693 | Avg Train Loss:0.867torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 59/100 | Avg Batch Loss: 0.715 | Batch Loss: 0.638 | Avg Train Loss:0.866torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 60/100 | Avg Batch Loss: 0.717 | Batch Loss: 0.862 | Avg Train Loss:0.866torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 61/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.632 | Avg Train Loss:0.864torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 62/100 | Avg Batch Loss: 0.715 | Batch Loss: 0.676 | Avg Train Loss:0.863torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 63/100 | Avg Batch Loss: 0.717 | Batch Loss: 0.786 | Avg Train Loss:0.863torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 64/100 | Avg Batch Loss: 0.716 | Batch Loss: 0.686 | Avg Train Loss:0.862torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 65/100 | Avg Batch Loss: 0.713 | Batch Loss: 0.519 | Avg Train Loss:0.86torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 66/100 | Avg Batch Loss: 0.713 | Batch Loss: 0.691 | Avg Train Loss:0.859torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 67/100 | Avg Batch Loss: 0.711 | Batch Loss: 0.589 | Avg Train Loss:0.857torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 68/100 | Avg Batch Loss: 0.708 | Batch Loss: 0.538 | Avg Train Loss:0.855torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 69/100 | Avg Batch Loss: 0.71 | Batch Loss: 0.837 | Avg Train Loss:0.855torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 70/100 | Avg Batch Loss: 0.709 | Batch Loss: 0.62 | Avg Train Loss:0.854torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 71/100 | Avg Batch Loss: 0.708 | Batch Loss: 0.623 | Avg Train Loss:0.852torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 72/100 | Avg Batch Loss: 0.704 | Batch Loss: 0.428 | Avg Train Loss:0.85torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 73/100 | Avg Batch Loss: 0.704 | Batch Loss: 0.755 | Avg Train Loss:0.849torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 74/100 | Avg Batch Loss: 0.705 | Batch Loss: 0.718 | Avg Train Loss:0.848torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 75/100 | Avg Batch Loss: 0.703 | Batch Loss: 0.569 | Avg Train Loss:0.847torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 76/100 | Avg Batch Loss: 0.702 | Batch Loss: 0.625 | Avg Train Loss:0.846torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 77/100 | Avg Batch Loss: 0.699 | Batch Loss: 0.475 | Avg Train Loss:0.843torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 78/100 | Avg Batch Loss: 0.697 | Batch Loss: 0.57 | Avg Train Loss:0.842torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 79/100 | Avg Batch Loss: 0.696 | Batch Loss: 0.634 | Avg Train Loss:0.841torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 80/100 | Avg Batch Loss: 0.695 | Batch Loss: 0.574 | Avg Train Loss:0.839torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 81/100 | Avg Batch Loss: 0.692 | Batch Loss: 0.489 | Avg Train Loss:0.837torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 82/100 | Avg Batch Loss: 0.693 | Batch Loss: 0.743 | Avg Train Loss:0.837torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 83/100 | Avg Batch Loss: 0.691 | Batch Loss: 0.572 | Avg Train Loss:0.835torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 84/100 | Avg Batch Loss: 0.689 | Batch Loss: 0.487 | Avg Train Loss:0.834torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 85/100 | Avg Batch Loss: 0.691 | Batch Loss: 0.839 | Avg Train Loss:0.834torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 86/100 | Avg Batch Loss: 0.688 | Batch Loss: 0.422 | Avg Train Loss:0.831torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 87/100 | Avg Batch Loss: 0.691 | Batch Loss: 1.01 | Avg Train Loss:0.832torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 88/100 | Avg Batch Loss: 0.69 | Batch Loss: 0.555 | Avg Train Loss:0.831torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 89/100 | Avg Batch Loss: 0.687 | Batch Loss: 0.434 | Avg Train Loss:0.829torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 90/100 | Avg Batch Loss: 0.685 | Batch Loss: 0.53 | Avg Train Loss:0.827torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 91/100 | Avg Batch Loss: 0.685 | Batch Loss: 0.688 | Avg Train Loss:0.826torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 92/100 | Avg Batch Loss: 0.685 | Batch Loss: 0.659 | Avg Train Loss:0.826torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 93/100 | Avg Batch Loss: 0.686 | Batch Loss: 0.744 | Avg Train Loss:0.825torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 94/100 | Avg Batch Loss: 0.686 | Batch Loss: 0.743 | Avg Train Loss:0.825torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 95/100 | Avg Batch Loss: 0.685 | Batch Loss: 0.541 | Avg Train Loss:0.823torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 96/100 | Avg Batch Loss: 0.685 | Batch Loss: 0.757 | Avg Train Loss:0.823torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 97/100 | Avg Batch Loss: 0.686 | Batch Loss: 0.709 | Avg Train Loss:0.822torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 98/100 | Avg Batch Loss: 0.683 | Batch Loss: 0.393 | Avg Train Loss:0.82torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 99/100 | Avg Batch Loss: 0.682 | Batch Loss: 0.613 | Avg Train Loss:0.819torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 100/100 | Avg Batch Loss: 0.681 | Batch Loss: 0.63 | Avg Train Loss:0.818
# Epoch: 3
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 1/100 | Avg Batch Loss: 0.869 | Batch Loss: 0.869 | Avg Train Loss:0.818torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 2/100 | Avg Batch Loss: 0.674 | Batch Loss: 0.48 | Avg Train Loss:0.817torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 3/100 | Avg Batch Loss: 0.678 | Batch Loss: 0.686 | Avg Train Loss:0.816torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 4/100 | Avg Batch Loss: 0.647 | Batch Loss: 0.554 | Avg Train Loss:0.815torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 5/100 | Avg Batch Loss: 0.66 | Batch Loss: 0.712 | Avg Train Loss:0.814torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 6/100 | Avg Batch Loss: 0.693 | Batch Loss: 0.86 | Avg Train Loss:0.815torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 7/100 | Avg Batch Loss: 0.701 | Batch Loss: 0.747 | Avg Train Loss:0.814torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 8/100 | Avg Batch Loss: 0.703 | Batch Loss: 0.717 | Avg Train Loss:0.814torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 9/100 | Avg Batch Loss: 0.693 | Batch Loss: 0.611 | Avg Train Loss:0.813torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 10/100 | Avg Batch Loss: 0.713 | Batch Loss: 0.892 | Avg Train Loss:0.813torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 11/100 | Avg Batch Loss: 0.692 | Batch Loss: 0.48 | Avg Train Loss:0.812torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 12/100 | Avg Batch Loss: 0.678 | Batch Loss: 0.53 | Avg Train Loss:0.81torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 13/100 | Avg Batch Loss: 0.666 | Batch Loss: 0.526 | Avg Train Loss:0.809torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 14/100 | Avg Batch Loss: 0.658 | Batch Loss: 0.547 | Avg Train Loss:0.808torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 15/100 | Avg Batch Loss: 0.654 | Batch Loss: 0.601 | Avg Train Loss:0.807torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 16/100 | Avg Batch Loss: 0.652 | Batch Loss: 0.616 | Avg Train Loss:0.806torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 17/100 | Avg Batch Loss: 0.661 | Batch Loss: 0.816 | Avg Train Loss:0.806torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 18/100 | Avg Batch Loss: 0.657 | Batch Loss: 0.582 | Avg Train Loss:0.805torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 19/100 | Avg Batch Loss: 0.664 | Batch Loss: 0.783 | Avg Train Loss:0.805torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 20/100 | Avg Batch Loss: 0.66 | Batch Loss: 0.594 | Avg Train Loss:0.804torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 21/100 | Avg Batch Loss: 0.659 | Batch Loss: 0.636 | Avg Train Loss:0.803torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 22/100 | Avg Batch Loss: 0.654 | Batch Loss: 0.559 | Avg Train Loss:0.802torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 23/100 | Avg Batch Loss: 0.649 | Batch Loss: 0.529 | Avg Train Loss:0.801torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 24/100 | Avg Batch Loss: 0.648 | Batch Loss: 0.632 | Avg Train Loss:0.8torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 25/100 | Avg Batch Loss: 0.651 | Batch Loss: 0.728 | Avg Train Loss:0.8torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 26/100 | Avg Batch Loss: 0.647 | Batch Loss: 0.526 | Avg Train Loss:0.798torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 27/100 | Avg Batch Loss: 0.648 | Batch Loss: 0.694 | Avg Train Loss:0.798torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 28/100 | Avg Batch Loss: 0.651 | Batch Loss: 0.71 | Avg Train Loss:0.798torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 29/100 | Avg Batch Loss: 0.646 | Batch Loss: 0.526 | Avg Train Loss:0.796torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 30/100 | Avg Batch Loss: 0.644 | Batch Loss: 0.569 | Avg Train Loss:0.795torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 31/100 | Avg Batch Loss: 0.645 | Batch Loss: 0.671 | Avg Train Loss:0.795torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 32/100 | Avg Batch Loss: 0.642 | Batch Loss: 0.572 | Avg Train Loss:0.794torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 33/100 | Avg Batch Loss: 0.641 | Batch Loss: 0.586 | Avg Train Loss:0.793torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 34/100 | Avg Batch Loss: 0.642 | Batch Loss: 0.699 | Avg Train Loss:0.793torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 35/100 | Avg Batch Loss: 0.637 | Batch Loss: 0.455 | Avg Train Loss:0.791torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 36/100 | Avg Batch Loss: 0.642 | Batch Loss: 0.813 | Avg Train Loss:0.791torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 37/100 | Avg Batch Loss: 0.638 | Batch Loss: 0.515 | Avg Train Loss:0.79torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 38/100 | Avg Batch Loss: 0.636 | Batch Loss: 0.548 | Avg Train Loss:0.789torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 39/100 | Avg Batch Loss: 0.64 | Batch Loss: 0.808 | Avg Train Loss:0.789torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 40/100 | Avg Batch Loss: 0.646 | Batch Loss: 0.848 | Avg Train Loss:0.789torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 41/100 | Avg Batch Loss: 0.646 | Batch Loss: 0.659 | Avg Train Loss:0.789torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 42/100 | Avg Batch Loss: 0.648 | Batch Loss: 0.728 | Avg Train Loss:0.789torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 43/100 | Avg Batch Loss: 0.651 | Batch Loss: 0.764 | Avg Train Loss:0.789torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 44/100 | Avg Batch Loss: 0.643 | Batch Loss: 0.319 | Avg Train Loss:0.787torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 45/100 | Avg Batch Loss: 0.64 | Batch Loss: 0.487 | Avg Train Loss:0.785torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 46/100 | Avg Batch Loss: 0.642 | Batch Loss: 0.76 | Avg Train Loss:0.785torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 47/100 | Avg Batch Loss: 0.641 | Batch Loss: 0.568 | Avg Train Loss:0.784torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 48/100 | Avg Batch Loss: 0.64 | Batch Loss: 0.621 | Avg Train Loss:0.784torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 49/100 | Avg Batch Loss: 0.634 | Batch Loss: 0.325 | Avg Train Loss:0.782torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 50/100 | Avg Batch Loss: 0.636 | Batch Loss: 0.738 | Avg Train Loss:0.782torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 51/100 | Avg Batch Loss: 0.635 | Batch Loss: 0.613 | Avg Train Loss:0.781torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 52/100 | Avg Batch Loss: 0.64 | Batch Loss: 0.872 | Avg Train Loss:0.781torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# ...
# Batch: 17/100 | Avg Batch Loss: 0.149 | Batch Loss: 0.133 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 18/100 | Avg Batch Loss: 0.151 | Batch Loss: 0.176 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 19/100 | Avg Batch Loss: 0.152 | Batch Loss: 0.172 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 20/100 | Avg Batch Loss: 0.151 | Batch Loss: 0.141 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 21/100 | Avg Batch Loss: 0.153 | Batch Loss: 0.185 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 22/100 | Avg Batch Loss: 0.153 | Batch Loss: 0.146 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 23/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.207 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 24/100 | Avg Batch Loss: 0.153 | Batch Loss: 0.103 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 25/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.212 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 26/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.224 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 27/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.0854 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 28/100 | Avg Batch Loss: 0.154 | Batch Loss: 0.117 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 29/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.221 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 30/100 | Avg Batch Loss: 0.154 | Batch Loss: 0.103 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 31/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.169 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 32/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.167 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 33/100 | Avg Batch Loss: 0.154 | Batch Loss: 0.113 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 34/100 | Avg Batch Loss: 0.153 | Batch Loss: 0.115 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 35/100 | Avg Batch Loss: 0.152 | Batch Loss: 0.113 | Avg Train Loss:0.295torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 36/100 | Avg Batch Loss: 0.151 | Batch Loss: 0.119 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 37/100 | Avg Batch Loss: 0.152 | Batch Loss: 0.188 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 38/100 | Avg Batch Loss: 0.154 | Batch Loss: 0.242 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 39/100 | Avg Batch Loss: 0.153 | Batch Loss: 0.11 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 40/100 | Avg Batch Loss: 0.152 | Batch Loss: 0.123 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 41/100 | Avg Batch Loss: 0.151 | Batch Loss: 0.118 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 42/100 | Avg Batch Loss: 0.151 | Batch Loss: 0.155 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 43/100 | Avg Batch Loss: 0.152 | Batch Loss: 0.174 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 44/100 | Avg Batch Loss: 0.151 | Batch Loss: 0.121 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 45/100 | Avg Batch Loss: 0.153 | Batch Loss: 0.238 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 46/100 | Avg Batch Loss: 0.154 | Batch Loss: 0.17 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 47/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.237 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 48/100 | Avg Batch Loss: 0.154 | Batch Loss: 0.111 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 49/100 | Avg Batch Loss: 0.155 | Batch Loss: 0.197 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 50/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.204 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 51/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.162 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 52/100 | Avg Batch Loss: 0.159 | Batch Loss: 0.28 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 53/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.119 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 54/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.142 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 55/100 | Avg Batch Loss: 0.159 | Batch Loss: 0.213 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 56/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.118 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 57/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.117 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 58/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.147 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 59/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.189 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 60/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.159 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 61/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.134 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 62/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.159 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 63/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.176 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 64/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.156 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 65/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.105 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 66/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.172 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 67/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.172 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 68/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.159 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 69/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.22 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 70/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.125 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 71/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.157 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 72/100 | Avg Batch Loss: 0.159 | Batch Loss: 0.246 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 73/100 | Avg Batch Loss: 0.159 | Batch Loss: 0.158 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 74/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.0991 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 75/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.15 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 76/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.173 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 77/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.0999 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 78/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.13 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 79/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.135 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 80/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.124 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 81/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.169 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 82/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.201 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 83/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.083 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 84/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.169 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 85/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.227 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 86/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.195 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 87/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.117 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 88/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.136 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 89/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.213 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 90/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.123 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 91/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.0877 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 92/100 | Avg Batch Loss: 0.156 | Batch Loss: 0.129 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 93/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.22 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 94/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.174 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 95/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.122 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 96/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.214 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 97/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.23 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 98/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.183 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 99/100 | Avg Batch Loss: 0.158 | Batch Loss: 0.118 | Avg Train Loss:0.294torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# torch.Size([10, 1]) torch.Size([10])
# Batch: 100/100 | Avg Batch Loss: 0.157 | Batch Loss: 0.113 | Avg Train Loss:0.294
# w:
# tensor([[1.1613],
#         [1.0093]])
#
# b:
# tensor([-6.1174])

# %% [markdown]
# # <font style="color:blue">11. Plot the Decision Boundary</font>
# We will plot the decision boundary using the weight and biases obtained from training the network.

# %%
plt.scatter(class_zero_points[:,0], class_zero_points[:,1], s=8, color='b', label='Class:0')
plt.scatter(class_one_points[:,0], class_one_points[:,1], s=8, color='r', label='Class:1')
x1 = torch.linspace(-1, 8, 1000)
x2 = -(b.data[0] + w.data[0][0] * x1)/ w.data[1][0]
plt.plot(x1, x2, c='g', label='Learned decision boundary:\n{0:.2}x1 + {1:.2}x2 + {2:.2} = 0'.
         format(w.data[0][0], w.data[1][0], b.data[0]))
plt.legend()
plt.xlim([-1, 8])
plt.ylim([-1, 8])
plt.xlabel('x1')
plt.ylabel('x2')
# Out:
# (-1.0, 8.0)
# (-1.0, 8.0)
# Text(0.5, 0, 'x1')
# Text(0, 0.5, 'x2')

# %% [markdown]
# # <font style="color:blue">12. Plot the Loss Curve</font>

# %%
plt.rcParams["figure.figsize"] = (15, 8)
plt.figure
plt.plot(range(len(avg_train_loss)), avg_train_loss)
plt.xlabel('Batch no.')
plt.ylabel('Batch Loss')
plt.show()
# Out:
# <function matplotlib.pyplot.figure(num: 'int | str | Figure | SubFigure | None' = None, figsize: 'ArrayLike | None' = None, dpi: 'float | None' = None, *, facecolor: 'ColorType | None' = None, edgecolor: 'ColorType | None' = None, frameon: 'bool' = True, FigureClass: 'type[Figure]' = <class 'matplotlib.figure.Figure'>, clear: 'bool' = False, **kwargs) -> 'Figure'>
# Text(0.5, 0, 'Batch no.')
# Text(0, 0.5, 'Batch Loss')

# %% [markdown]
# # <font style="color:blue">13. Accuracy</font>

# %%
def accuracy(w, b, inputs, label):
    bc = BinaryClassifierGraph()
    prediction = bc.forward(w, inputs, b)
    pred = prediction >= 0.5
    pred = pred.squeeze()
    label = label.type(torch.bool)
    count = len(label)
    
    correct_pred = torch.sum(torch.eq(pred, label))
    accuracy = correct_pred * 1.0/count
    return accuracy

# %%
accuracy(w, b, data_points, label)
# Out:
# torch.Size([1000, 1]) torch.Size([1000])
# tensor(0.9890)

# %% [markdown]
# # <font style="color:blue">14. Decision Boundary Animation</font>
# We have saved the weights at the end of each epoch. So, we can plot them and see how the weights got updated and how decision boundary changed before it converged.

# %%
# %matplotlib notebook
# %matplotlib ipympl

plt.rcParams["figure.figsize"] = (10, 10)

fig, ax = plt.subplots()

ax.set_xlim(-1, 8)
ax.set_ylim(-1, 8)
ax.set_xlabel('x1')
ax.set_ylabel('x2')

line, = ax.plot(0, 0, color='g', label='Decision Boundary')
ax.scatter(class_zero_points[:,0], class_zero_points[:,1], s=8, color='b', label='Class:0')
ax.scatter(class_one_points[:,0], class_one_points[:,1], s=8, color='r', label='Class:1')
ax.legend(loc='upper right')

def plot_points_line(parm, line):
    x1 = torch.linspace(-1, 8, 1000)
    x2 = -(parm[2] + parm[0] * x1)/ parm[1]
    line.set_xdata(x1)
    line.set_ydata(x2)
    return line, 
    

line_animation = animation.FuncAnimation(fig, func=plot_points_line, frames=updated_parms, fargs=(line,),
                                         interval=200)
plt.show()
# Out:
# (-1.0, 8.0)
# (-1.0, 8.0)
# Text(0.5, 0, 'x1')
# Text(0, 0.5, 'x2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## <font style="color:rgb(8,133,37)">Exercise</font>
#
# 1. Try to use MSE loss and see if it converges to an optimal solution. If not, find the reason. Check if the vanishing gradient is the culprit.
#
# 2. Instead of using the chain rule, derive the gradient function of the whole graph, and try using this for gradient update. For deriving the gradient function, you can use the chain rule.
