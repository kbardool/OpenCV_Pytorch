# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2A: Get the Data](#step2a)
# - [Step 2B: Explore the Data](#step2b)
# - [Step 2C: Create Sample Data](#step2c)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#predictions)
# - [Step 6. Display Mistakes](#display)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 1: Data Understanding & Pipeline Check</font>
#
# Here, we will slightly modify the steps  we had used to train Neural Networks:
#
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data, and check the pipeline before training the full network
# - Step 5 - Train on full Data
# - Step 6 - Improve your model
#
#
# In this notebook we will detail the steps 1 to 4, and do some coding along the way! You will implement Steps 5 & 6 in the next notebook.
#
# This notebook contains  30 points. <font style="color:red">The sections in red are the ones that carry marks.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your Problem </font><a name="step1"></a>
#
# As you already know, Image Classification helps classify an image based on its visual content. So, the model is supposed to look at the given image and predict which object is present in it. Obviously, the number of objects which it can predict depends on how many you trained it on.
#
#
# In our problem, we want to classify an input image between **3 animals - Cat, Dog and Panda**.
#
# ### <font style="color:green">What Do We Need and How to Achieve It? </font>
#
# You need correctly-labelled images of each animal. Train a decent-sized network to , understand the input image.

# %% [markdown]
# # <font style="color:blue">Step 2A: Get the Data </font><a name="step2a"></a>
#
# Let’s use a dataset from kaggle. [**Check it out here**](https://www.kaggle.com/ashishsaxena2209/animal-image-datasetdog-cat-and-panda).
#
# It has separate folders for each animal, each consisting of `1000` images. We have split it into `80:20` ratio for `train:validation`. To download, [**click  here**](https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1).

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip
# Out:
# --2026-01-21 07:12:51--  https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fo/t88xubtku433w1t10t7he/AEmJ4AwgZ3Svjp29IdawVbE?rlkey=9vuxo0sqr57tsoqn8wgk9pjzc&dl=1 [following]
# --2026-01-21 07:12:51--  https://www.dropbox.com/scl/fo/t88xubtku433w1t10t7he/AEmJ4AwgZ3Svjp29IdawVbE?rlkey=9vuxo0sqr57tsoqn8wgk9pjzc&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc48ba23dd129f5e5cccc8379e5f.dl.dropboxusercontent.com/zip_download_get/CczeekuEidqmKTbo2KJ66OYGvlSzrr3Wb0CfsP3BMR_HMfETkQShXLseGGYKev1H1wR5DtTL75vdatH0r0tSEONMi2NqeN556RWS1P23SHXuIQ# [following]
# --2026-01-21 07:12:54--  https://uc48ba23dd129f5e5cccc8379e5f.dl.dropboxusercontent.com/zip_download_get/CczeekuEidqmKTbo2KJ66OYGvlSzrr3Wb0CfsP3BMR_HMfETkQShXLseGGYKev1H1wR5DtTL75vdatH0r0tSEONMi2NqeN556RWS1P23SHXuIQ
# Resolving uc48ba23dd129f5e5cccc8379e5f.dl.dropboxusercontent.com (uc48ba23dd129f5e5cccc8379e5f.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6017:15::a27d:20f
# Connecting to uc48ba23dd129f5e5cccc8379e5f.dl.dropboxusercontent.com (uc48ba23dd129f5e5cccc8379e5f.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197683526 (189M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip              4%[                    ]   9.37M  1.68MB/s    eta 2m 0s  ^C

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
# !unzip -q data.zip
# Out:
# [data.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of data.zip or
#         data.zip.zip, and cannot find data.zip.ZIP, period.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <font style="color:blue">Step 2B: Explore the Data [5 Points]</font><a name="step2b"></a>
#
# Here are  some examples:

# %% [markdown]
# ### <font style="color:green">Folder Structure </font>

# %%
# !tree -d ./cat-dog-panda
# Out:
# ./cat-dog-panda
# ├── training
# │   ├── cat
# │   ├── dog
# │   └── panda
# └── validation
#     ├── cat
#     ├── dog
#     └── panda
#
# 8 directories

# %% [markdown]
# ### <font style="color:green">Import the Datasets Module</font>
#
# Load the data,  using the datasets module, and . , check out its structure .

# %%
from torchvision import datasets

# %% [markdown]
# ### <font style="color:green">Create a Dataset Object </font>

# %%
train_data = datasets.ImageFolder("./cat-dog-panda/training")
validation_data = datasets.ImageFolder("./cat-dog-panda/validation")
print(type(train_data))
# Out:
# <class 'torchvision.datasets.folder.ImageFolder'>

# %% [markdown]
# ### <font style="color:green">List the Classes</font>
#
# It simply prints the sub folders present under the training or validation folder.

# %%
print(train_data.classes)
print(validation_data.classes)
# Out:
# ['cat', 'dog', 'panda']
# ['cat', 'dog', 'panda']

# %% [markdown]
# ### <font style="color:green">Get the Class ID to Name Mapping</font>

# %%
print(train_data.class_to_idx)
print(validation_data.class_to_idx)
# Out:
# {'cat': 0, 'dog': 1, 'panda': 2}
# {'cat': 0, 'dog': 1, 'panda': 2}

# %% [markdown]
# ### <font style="color:red">Find the Number of Samples in Training and Validation Folders [2 Points]</font>

# %%
# Enter Code Here
print(f" number of training samples:  {len(train_data)}   type: {type(train_data)}  " )
print(f" number of training samples:  {len(validation_data)}" )
# Out:
#  number of training samples:  2400   type: <class 'torchvision.datasets.folder.ImageFolder'>
#  number of training samples:  600

# %% [markdown]
# ### <font style="color:red">Display Some Samples [3 Points]</font>
# Display one sample from each class. We know that the train dataset contains
#
# - cats from 0 to 799
# - dogs from 800 to 1599
# - pandas from 1600 to 2399
#
# Take one sample from each class and display using matplotlib

# %%
train_data[800]
# Out:
# (<PIL.Image.Image image mode=RGB size=382x478>, 1)

# %%
# Enter Code Here
idxs = np.random.randint(0,800,3)
plt.style.use('default')
plt.rcParams["figure.figsize"] = (12, 4)
fig = plt.figure()
    
for i, idx  in enumerate(idxs):
    plt.subplot(1, 3, i+1)
    # img = transforms.functional.to_pil_image(imgs[i])
    plt.imshow(train_data[idx][0])
    plt.gca().set_title(f"idx:{idx}  ({train_data.classes[train_data[idx][1]]})"
                         " size: {img.size} ", fontsize=9)
fig.savefig('samples_dog.png')
plt.show()

# %%
# Enter Code Here
idxs = np.random.randint(800,1600,3)
plt.style.use('default')
plt.rcParams["figure.figsize"] = (12, 4)
fig = plt.figure()
    
for i, idx  in enumerate(idxs):
    plt.subplot(1, 3, i+1)
    # img = transforms.functional.to_pil_image(imgs[i])
    plt.imshow(train_data[idx][0])
    plt.gca().set_title('idx:{0}  ({1:.2})'.format(idx, 
                                                 train_data.classes[train_data[idx][1]]), fontsize=9)
fig.savefig('samples_dog.png')
plt.show()

# %%
# Enter Code Here
idxs = np.random.randint(1600, 2400, 3)
plt.style.use('default')
plt.rcParams["figure.figsize"] = (12, 4)
fig = plt.figure()
    
for i, idx  in enumerate(idxs):
    plt.subplot(1, 3, i+1)
    # img = transforms.functional.to_pil_image(imgs[i])
    plt.imshow(train_data[idx][0])
    plt.gca().set_title('idx:{0}  ({1:.2})'.format(idx, 
                                                 train_data.classes[train_data[idx][1]]), fontsize=9)
fig.savefig('samples_dog.png')
plt.show()

# %% [markdown]
# **Note:** The images are all of different size.

# %% [markdown]
# # <font style="color:blue">Step 2C: Create Sample Data</font><a name="step2c"></a>
#
# Take `5%` images from training and validation to create a small sample dataset, which will check our training pipeline.

# %%
import torch
import numpy as np

# %%
subset_size = .05
print(1./subset_size)
# Out:
# 20.0

# %% [markdown]
# ### <font style="color:green">Create a Subset From the Original Data</font>
#
# Instead of copying the original data, use the `Subset` method in `Torch` to create a subset of the data. And use this to train the model.
#
#
# This is new. Let’ss see how it is done.

# %%
train_subset = torch.utils.data.Subset(train_data,np.arange(0,len(train_data),1./subset_size))
validation_subset = torch.utils.data.Subset(validation_data,np.arange(0,len(validation_data),1./subset_size))

# %%
train_subset_loader = torch.utils.data.DataLoader(train_subset,
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)
validation_subset_loader = torch.utils.data.DataLoader(validation_subset, 
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)

# %%
print("Train Subset Size: {}".format(len(train_subset_loader.dataset)))
print("Validation Subset Size: {}".format(len(validation_subset_loader.dataset)))
# Out:
# Train Subset Size: 120
# Validation Subset Size: 30

# %% [markdown]
# You can see that the subset data is only 5% of the original training and validation data.

# %% [markdown]
# We will create a separate function called `subset_data_loader` to create data loaders for subsets.

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation [5 Points]</font>  <a name="step3"></a>
#
# Now that you have seen how the data is organized, configure the train and test loaders to feed  the training pipeline.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ## <font style="color:blue">3.2. Image Transforms</font>
#
# We need to normalize the data. Some of the  standard ways of doing it is to, subtract the mean, make all images equal in size or to rescale the range to \[0,1\] etc. , Use the following functions to do this:
#
# - just like `image_preprocess_transforms`, `image_common_transforms` should also be applied _**irrespective of whether we have training set or validation set**_!
# - However since **data augmentation** would be applicable to the **training set** only, you should write a separate function for that!
# - Normalization is usually the last preprocessing step to be performed before training

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>
# Normalize for mean and std.
#
# You can add any other transforms here as per your dataset.

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), 
                            std=(0.2193, 0.2150, 0.2109)):
    
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>
# Function for getting mean and variance

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)
    
    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)
    
    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i] 
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]
    
    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)
    
    # var[X] = E[X**2] - E[X]**2
    
    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2
    
    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)
    std = var ** 0.5
    
    return mean, std

# %%
me, st = get_mean_std('./cat-dog-panda/training')
print(f" training mean and std   : mean: {me}   std: {st}")
me, st = get_mean_std('./cat-dog-panda/validation')
print(f" validation mean and std : mean: {me}   std: {st}")
me, st = get_mean_std('./cat-dog-panda')
print(f" train & validation      : mean: {me}   std: {st}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 me, st = get_mean_std('./cat-dog-panda/training')
#       2 print(f" training mean and std   : mean: {me}   std: {st}")
#       3 me, st = get_mean_std('./cat-dog-panda/validation')
#
# Cell In[32], line 5, in get_mean_std(data_root, num_workers)
#       1 def get_mean_std(data_root, num_workers=4):
#       3     transform = image_preprocess_transforms()
# ----> 5     loader = data_loader(data_root, transform)
#       7     batch_mean = torch.zeros(3)
#       8     batch_mean_sqrd = torch.zeros(3)
#
# NameError: name 'data_loader' is not defined

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
#
# Data loader used by the training routine to  generate batches of data:

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ### <font style="color:green">3.3.2. Data Loader for Subset</font>
# Data loader which uses the `subset` to generate batches

# %%
def subset_data_loader(data_root, transform, batch_size=8, shuffle=False, num_workers=2, subset_size=0.05):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    data_subset = torch.utils.data.Subset(dataset,np.arange(0,len(dataset),1./subset_size).astype(int))

    loader = torch.utils.data.DataLoader(data_subset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:red">3.4. Prepare Data [5 Points]</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')

    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
    # if data_augmentation is true 
    if data_augmentation:    
        # ERROR #1: data augmentation_process has not been implemented
        # we should implement this 
        train_transforms = data_augmentation_preprocess(mean, std) 
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    
    train_loader = subset_data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    
    test_data_path = os.path.join(data_root, 'validation')

    ## ERROR #2: train_transforms should not be used here, to 
    ## prevent data augumentations being applied to test data
    test_loader = subset_data_loader(test_data_path, 
                              train_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    return train_loader, test_loader

# %%
trn_loader, tst_loader = get_data(batch_size=8, data_root='./cat-dog-panda', data_augmentation=False)

# %%
## Based on training data only - mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
## Based on (training and validation data) -  mean: tensor([0.4615, 0.4358, 0.3917]), std: tensor([0.2743, 0.2653, 0.2631])

# %% [markdown]
# ### <font style="color:red">Question </font>[5 Points]
#
# There are two mistakes in the above code snippet. Spot the errors and correct them all. (Note: The rest of the code will run, even if you fail to find the mistakes.)

# %% [markdown]
# # <font style="color:blue">Step 4: Train a Simple Model</font><a name="step4"></a>
#
# It is time to create the training pipeline and train a simple model on the sample data. We provide most of the code in this section. In the next notebook,  you  are the one who will have to make all the changes.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [ 5 Points]</font>
#
# In this section, define the training  and system configurations. Also, specify the batch size, data path, learning rate etc.
#
#
# ### <font style="color:red">Question </font>[5 Points]:
#
# Set up the training pipeline with a batch size of `4`. Run the experiment then for `100` epochs. Change the configurations as given below:

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4
    epochs_count: int = 100  
    init_learning_rate: float = 0.0001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You already know the training function. No need to make any changes:

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
):
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
):
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        with torch.no_grad():
            output = model(data)
        
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Please note here that before calling the train function, we calculate the validation loss.  It should be close to $log(\text{num_classes})$ and the accuracy should be close to  $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">4.8. Define Model</font>
#
# In the section,  define the CNN model and train the model.

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )

        
        # Fully connected layers
        self._head = nn.Sequential(
            nn.Linear(in_features=64*52*52, out_features=1024), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=1024, out_features=3)
            
        )
    
    def forward(self, x):
        
        # apply feature extractor
        x = self._body(x)
        # flatten the output of conv layers
        # dimension should be batch_size * number_of weight_in_last conv_layer
        x = x.view(x.size()[0], -1)
        # apply classification head
        x = self._head(x)
        
        
        return x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 class MyModel(nn.Module):
#       2     def __init__(self):
#       3         super().__init__()
#
# NameError: name 'nn' is not defined

# %%
my_model = MyModel()
print(my_model)
from torchinfo import summary
col_names = ("input_size", "output_size", "num_params", "params_percent", 
             "kernel_size", "mult_adds",  "trainable" )
batch_size = 4
input_size = (batch_size, 3, 224, 224)

# summary(my_model.body, input_size = (batch_size,3, 32, 32), col_names=col_names)
summary(my_model, input_size=input_size, col_names=col_names)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=173056, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=3, bias=True)
#   )
# )
# =======================================================================================================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Param %                   Kernel Shape              Mult-Adds                 Trainable
# =======================================================================================================================================================================================================================
# MyModel                                  [4, 3, 224, 224]          [4, 3]                    --                             --                   --                        --                        True
# ├─Sequential: 1-1                        [4, 3, 224, 224]          [4, 64, 52, 52]           --                             --                   --                        --                        True
# │    └─Conv2d: 2-1                       [4, 3, 224, 224]          [4, 32, 218, 218]         4,736                       0.00%                   [7, 7]                    900,294,656               True
# │    └─ReLU: 2-2                         [4, 32, 218, 218]         [4, 32, 218, 218]         --                             --                   --                        --                        --
# │    └─MaxPool2d: 2-3                    [4, 32, 218, 218]         [4, 32, 109, 109]         --                             --                   2                         --                        --
# │    └─Conv2d: 2-4                       [4, 32, 109, 109]         [4, 64, 105, 105]         51,264                      0.03%                   [5, 5]                    2,260,742,400             True
# │    └─ReLU: 2-5                         [4, 64, 105, 105]         [4, 64, 105, 105]         --                             --                   --                        --                        --
# │    └─MaxPool2d: 2-6                    [4, 64, 105, 105]         [4, 64, 52, 52]           --                             --                   2                         --                        --
# ├─Sequential: 1-2                        [4, 173056]               [4, 3]                    --                             --                   --                        --                        True
# │    └─Linear: 2-7                       [4, 173056]               [4, 1024]                 177,210,368                99.97%                   --                        708,841,472               True
# │    └─ReLU: 2-8                         [4, 1024]                 [4, 1024]                 --                             --                   --                        --                        --
# │    └─Linear: 2-9                       [4, 1024]                 [4, 3]                    3,075                       0.00%                   --                        12,300                    True
# =======================================================================================================================================================================================================================
# Total params: 177,269,443
# Trainable params: 177,269,443
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 3.87
# =======================================================================================================================================================================================================================
# Input size (MB): 2.41
# Forward/backward pass size (MB): 71.28
# Params size (MB): 709.08
# Estimated Total Size (MB): 782.76
# =======================================================================================================================================================================================================================

# %% [markdown]
# ## <font style="color:blue">4.9. Training</font>

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = MyModel()
#       2 print(model)
#       4 # get optimizer
#
# NameError: name 'MyModel' is not defined

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=False)
# Out:
# mean: tensor([0.4615, 0.4358, 0.3917]), std: tensor([0.2743, 0.2653, 0.2631])
#
# Test set: Average loss: 1.0943, Accuracy: 11/30 (37%)
#
# Initial Test Loss : 1.094277,
# Initial Test Accuracy : 36.667%
#
# Epoch: 0
# Train Loss: 1.292028 Acc: 0.4250
# Elapsed 4.14s, 4.14 s/epoch, 0.14 s/batch, ets 410.27s
#
# Test set: Average loss: 0.8924, Accuracy: 19/30 (63%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 0.638101 Acc: 0.7500
# Elapsed 20.55s, 10.27 s/epoch, 0.34 s/batch, ets 1006.78s
#
# Test set: Average loss: 0.8233, Accuracy: 20/30 (67%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 0.262437 Acc: 0.9417
# Elapsed 43.67s, 14.56 s/epoch, 0.49 s/batch, ets 1412.14s
#
# Test set: Average loss: 0.9249, Accuracy: 17/30 (57%)
#
# Epoch: 3
# Train Loss: 0.095449 Acc: 1.0000
# Elapsed 47.96s, 11.99 s/epoch, 0.40 s/batch, ets 1151.00s
#
# Test set: Average loss: 0.9983, Accuracy: 19/30 (63%)
#
# Epoch: 4
# Train Loss: 0.040285 Acc: 0.9917
# Elapsed 52.62s, 10.52 s/epoch, 0.35 s/batch, ets 999.79s
#
# Test set: Average loss: 0.8789, Accuracy: 18/30 (60%)
#
# Epoch: 5
# Train Loss: 0.010284 Acc: 1.0000
# Elapsed 59.28s, 9.88 s/epoch, 0.33 s/batch, ets 928.77s
#
# Test set: Average loss: 1.0474, Accuracy: 15/30 (50%)
#
# Epoch: 6
# Train Loss: 0.005035 Acc: 1.0000
# Elapsed 67.52s, 9.65 s/epoch, 0.32 s/batch, ets 897.00s
#
# Test set: Average loss: 1.0318, Accuracy: 18/30 (60%)
#
# Epoch: 7
# Train Loss: 0.002497 Acc: 1.0000
# Elapsed 75.11s, 9.39 s/epoch, 0.31 s/batch, ets 863.73s
#
# Test set: Average loss: 1.0472, Accuracy: 18/30 (60%)
#
# Epoch: 8
# Train Loss: 0.001638 Acc: 1.0000
# Elapsed 80.36s, 8.93 s/epoch, 0.30 s/batch, ets 812.53s
#
# Test set: Average loss: 1.0628, Accuracy: 20/30 (67%)
#
# Epoch: 9
# Train Loss: 0.001232 Acc: 1.0000
# Elapsed 85.15s, 8.51 s/epoch, 0.28 s/batch, ets 766.31s
#
# Test set: Average loss: 1.1066, Accuracy: 18/30 (60%)
#
# Epoch: 10
# Train Loss: 0.000950 Acc: 1.0000
# Elapsed 90.11s, 8.19 s/epoch, 0.27 s/batch, ets 729.07s
#
# Test set: Average loss: 1.1031, Accuracy: 18/30 (60%)
#
# Epoch: 11
# Train Loss: 0.000748 Acc: 1.0000
# Elapsed 96.97s, 8.08 s/epoch, 0.27 s/batch, ets 711.10s
#
# Test set: Average loss: 1.1234, Accuracy: 18/30 (60%)
#
# Epoch: 12
# Train Loss: 0.000621 Acc: 1.0000
# Elapsed 102.83s, 7.91 s/epoch, 0.26 s/batch, ets 688.20s
#
# Test set: Average loss: 1.1319, Accuracy: 18/30 (60%)
#
# Epoch: 13
# Train Loss: 0.000513 Acc: 1.0000
# Elapsed 108.80s, 7.77 s/epoch, 0.26 s/batch, ets 668.32s
#
# Test set: Average loss: 1.1492, Accuracy: 18/30 (60%)
#
# Epoch: 14
# Train Loss: 0.000431 Acc: 1.0000
# Elapsed 115.79s, 7.72 s/epoch, 0.26 s/batch, ets 656.12s
#
# Test set: Average loss: 1.1561, Accuracy: 18/30 (60%)
#
# Epoch: 15
# Train Loss: 0.000372 Acc: 1.0000
# Elapsed 121.66s, 7.60 s/epoch, 0.25 s/batch, ets 638.73s
#
# Test set: Average loss: 1.1737, Accuracy: 18/30 (60%)
#
# Epoch: 16
# Train Loss: 0.000328 Acc: 1.0000
# Elapsed 130.89s, 7.70 s/epoch, 0.26 s/batch, ets 639.05s
#
# Test set: Average loss: 1.1782, Accuracy: 19/30 (63%)
#
# Epoch: 17
# Train Loss: 0.000279 Acc: 1.0000
# Elapsed 137.07s, 7.62 s/epoch, 0.25 s/batch, ets 624.44s
#
# Test set: Average loss: 1.1896, Accuracy: 19/30 (63%)
#
# Epoch: 18
# Train Loss: 0.000244 Acc: 1.0000
# Elapsed 143.20s, 7.54 s/epoch, 0.25 s/batch, ets 610.49s
#
# Test set: Average loss: 1.2016, Accuracy: 18/30 (60%)
#
# Epoch: 19
# Train Loss: 0.000218 Acc: 1.0000
# Elapsed 148.62s, 7.43 s/epoch, 0.25 s/batch, ets 594.49s
#
# Test set: Average loss: 1.2120, Accuracy: 18/30 (60%)
#
# Epoch: 20
# Train Loss: 0.000194 Acc: 1.0000
# Elapsed 153.47s, 7.31 s/epoch, 0.24 s/batch, ets 577.35s
#
# Test set: Average loss: 1.2175, Accuracy: 18/30 (60%)
#
# Epoch: 21
# Train Loss: 0.000173 Acc: 1.0000
# Elapsed 161.33s, 7.33 s/epoch, 0.24 s/batch, ets 571.98s
#
# Test set: Average loss: 1.2281, Accuracy: 18/30 (60%)
#
# Epoch: 22
# Train Loss: 0.000156 Acc: 1.0000
# Elapsed 166.13s, 7.22 s/epoch, 0.24 s/batch, ets 556.18s
#
# Test set: Average loss: 1.2320, Accuracy: 18/30 (60%)
#
# Epoch: 23
# Train Loss: 0.000141 Acc: 1.0000
# Elapsed 172.60s, 7.19 s/epoch, 0.24 s/batch, ets 546.58s
#
# Test set: Average loss: 1.2379, Accuracy: 18/30 (60%)
#
# Epoch: 24
# Train Loss: 0.000126 Acc: 1.0000
# Elapsed 178.33s, 7.13 s/epoch, 0.24 s/batch, ets 535.00s
#
# Test set: Average loss: 1.2406, Accuracy: 18/30 (60%)
#
# Epoch: 25
# Train Loss: 0.000116 Acc: 1.0000
# Elapsed 184.23s, 7.09 s/epoch, 0.24 s/batch, ets 524.36s
#
# Test set: Average loss: 1.2516, Accuracy: 18/30 (60%)
#
# Epoch: 26
# Train Loss: 0.000107 Acc: 1.0000
# Elapsed 190.88s, 7.07 s/epoch, 0.24 s/batch, ets 516.07s
#
# Test set: Average loss: 1.2522, Accuracy: 18/30 (60%)
#
# Epoch: 27
# Train Loss: 0.000096 Acc: 1.0000
# Elapsed 197.09s, 7.04 s/epoch, 0.23 s/batch, ets 506.81s
#
# Test set: Average loss: 1.2707, Accuracy: 18/30 (60%)
#
# Epoch: 28
# Train Loss: 0.000088 Acc: 1.0000
# Elapsed 202.49s, 6.98 s/epoch, 0.23 s/batch, ets 495.75s
#
# Test set: Average loss: 1.2718, Accuracy: 17/30 (57%)
#
# Epoch: 29
# Train Loss: 0.000081 Acc: 1.0000
# Elapsed 207.22s, 6.91 s/epoch, 0.23 s/batch, ets 483.51s
#
# Test set: Average loss: 1.2711, Accuracy: 17/30 (57%)
#
# Epoch: 30
# Train Loss: 0.000074 Acc: 1.0000
# Elapsed 212.83s, 6.87 s/epoch, 0.23 s/batch, ets 473.73s
#
# Test set: Average loss: 1.2824, Accuracy: 17/30 (57%)
#
# Epoch: 31
# Train Loss: 0.000068 Acc: 1.0000
# Elapsed 218.68s, 6.83 s/epoch, 0.23 s/batch, ets 464.70s
#
# Test set: Average loss: 1.2809, Accuracy: 17/30 (57%)
#
# Epoch: 32
# Train Loss: 0.000064 Acc: 1.0000
# Elapsed 224.27s, 6.80 s/epoch, 0.23 s/batch, ets 455.35s
#
# Test set: Average loss: 1.2900, Accuracy: 17/30 (57%)
#
# Epoch: 33
# Train Loss: 0.000059 Acc: 1.0000
# Elapsed 231.60s, 6.81 s/epoch, 0.23 s/batch, ets 449.57s
#
# Test set: Average loss: 1.2978, Accuracy: 17/30 (57%)
#
# Epoch: 34
# Train Loss: 0.000055 Acc: 1.0000
# Elapsed 236.47s, 6.76 s/epoch, 0.23 s/batch, ets 439.16s
#
# Test set: Average loss: 1.3000, Accuracy: 17/30 (57%)
#
# Epoch: 35
# Train Loss: 0.000052 Acc: 1.0000
# Elapsed 241.66s, 6.71 s/epoch, 0.22 s/batch, ets 429.62s
#
# Test set: Average loss: 1.3081, Accuracy: 17/30 (57%)
#
# Epoch: 36
# Train Loss: 0.000049 Acc: 1.0000
# Elapsed 246.65s, 6.67 s/epoch, 0.22 s/batch, ets 419.97s
#
# Test set: Average loss: 1.3108, Accuracy: 17/30 (57%)
#
# Epoch: 37
# Train Loss: 0.000046 Acc: 1.0000
# Elapsed 252.28s, 6.64 s/epoch, 0.22 s/batch, ets 411.61s
#
# Test set: Average loss: 1.3111, Accuracy: 17/30 (57%)
#
# Epoch: 38
# Train Loss: 0.000043 Acc: 1.0000
# Elapsed 258.01s, 6.62 s/epoch, 0.22 s/batch, ets 403.56s
#
# Test set: Average loss: 1.3288, Accuracy: 17/30 (57%)
#
# Epoch: 39
# Train Loss: 0.000040 Acc: 1.0000
# Elapsed 265.97s, 6.65 s/epoch, 0.22 s/batch, ets 398.95s
#
# Test set: Average loss: 1.3229, Accuracy: 17/30 (57%)
#
# Epoch: 40
# Train Loss: 0.000038 Acc: 1.0000
# Elapsed 272.15s, 6.64 s/epoch, 0.22 s/batch, ets 391.63s
#
# Test set: Average loss: 1.3241, Accuracy: 17/30 (57%)
#
# Epoch: 41
# Train Loss: 0.000035 Acc: 1.0000
# Elapsed 278.87s, 6.64 s/epoch, 0.22 s/batch, ets 385.10s
#
# Test set: Average loss: 1.3353, Accuracy: 17/30 (57%)
#
# Epoch: 42
# Train Loss: 0.000034 Acc: 1.0000
# Elapsed 283.82s, 6.60 s/epoch, 0.22 s/batch, ets 376.22s
#
# Test set: Average loss: 1.3411, Accuracy: 17/30 (57%)
#
# Epoch: 43
# Train Loss: 0.000032 Acc: 1.0000
# Elapsed 288.14s, 6.55 s/epoch, 0.22 s/batch, ets 366.73s
#
# Test set: Average loss: 1.3382, Accuracy: 16/30 (53%)
#
# Epoch: 44
# Train Loss: 0.000030 Acc: 1.0000
# Elapsed 295.58s, 6.57 s/epoch, 0.22 s/batch, ets 361.27s
#
# Test set: Average loss: 1.3501, Accuracy: 17/30 (57%)
#
# Epoch: 45
# Train Loss: 0.000029 Acc: 1.0000
# Elapsed 304.58s, 6.62 s/epoch, 0.22 s/batch, ets 357.55s
#
# Test set: Average loss: 1.3519, Accuracy: 16/30 (53%)
#
# Epoch: 46
# Train Loss: 0.000027 Acc: 1.0000
# Elapsed 313.39s, 6.67 s/epoch, 0.22 s/batch, ets 353.39s
#
# Test set: Average loss: 1.3537, Accuracy: 16/30 (53%)
#
# Epoch: 47
# Train Loss: 0.000026 Acc: 1.0000
# Elapsed 320.03s, 6.67 s/epoch, 0.22 s/batch, ets 346.70s
#
# Test set: Average loss: 1.3644, Accuracy: 15/30 (50%)
#
# Epoch: 48
# Train Loss: 0.000025 Acc: 1.0000
# Elapsed 328.56s, 6.71 s/epoch, 0.22 s/batch, ets 341.97s
#
# Test set: Average loss: 1.3576, Accuracy: 16/30 (53%)
#
# Epoch: 49
# Train Loss: 0.000024 Acc: 1.0000
# Elapsed 335.41s, 6.71 s/epoch, 0.22 s/batch, ets 335.41s
#
# Test set: Average loss: 1.3673, Accuracy: 16/30 (53%)
#
# Epoch: 50
# Train Loss: 0.000023 Acc: 1.0000
# Elapsed 341.61s, 6.70 s/epoch, 0.22 s/batch, ets 328.21s
#
# Test set: Average loss: 1.3708, Accuracy: 15/30 (50%)
#
# Epoch: 51
# Train Loss: 0.000021 Acc: 1.0000
# Elapsed 347.37s, 6.68 s/epoch, 0.22 s/batch, ets 320.65s
#
# Test set: Average loss: 1.3744, Accuracy: 16/30 (53%)
#
# Epoch: 52
# Train Loss: 0.000020 Acc: 1.0000
# Elapsed 354.24s, 6.68 s/epoch, 0.22 s/batch, ets 314.14s
#
# Test set: Average loss: 1.3758, Accuracy: 16/30 (53%)
#
# Epoch: 53
# Train Loss: 0.000020 Acc: 1.0000
# Elapsed 360.09s, 6.67 s/epoch, 0.22 s/batch, ets 306.74s
#
# Test set: Average loss: 1.3823, Accuracy: 15/30 (50%)
#
# Epoch: 54
# Train Loss: 0.000019 Acc: 1.0000
# Elapsed 367.17s, 6.68 s/epoch, 0.22 s/batch, ets 300.41s
#
# Test set: Average loss: 1.3824, Accuracy: 15/30 (50%)
#
# Epoch: 55
# Train Loss: 0.000018 Acc: 1.0000
# Elapsed 372.34s, 6.65 s/epoch, 0.22 s/batch, ets 292.55s
#
# Test set: Average loss: 1.3817, Accuracy: 16/30 (53%)
#
# Epoch: 56
# Train Loss: 0.000017 Acc: 1.0000
# Elapsed 377.99s, 6.63 s/epoch, 0.22 s/batch, ets 285.15s
#
# Test set: Average loss: 1.3910, Accuracy: 15/30 (50%)
#
# Epoch: 57
# Train Loss: 0.000016 Acc: 1.0000
# Elapsed 383.53s, 6.61 s/epoch, 0.22 s/batch, ets 277.73s
#
# Test set: Average loss: 1.3962, Accuracy: 15/30 (50%)
#
# Epoch: 58
# Train Loss: 0.000016 Acc: 1.0000
# Elapsed 389.44s, 6.60 s/epoch, 0.22 s/batch, ets 270.63s
#
# Test set: Average loss: 1.3947, Accuracy: 15/30 (50%)
#
# Epoch: 59
# Train Loss: 0.000015 Acc: 1.0000
# Elapsed 396.87s, 6.61 s/epoch, 0.22 s/batch, ets 264.58s
#
# Test set: Average loss: 1.4000, Accuracy: 15/30 (50%)
#
# Epoch: 60
# Train Loss: 0.000015 Acc: 1.0000
# Elapsed 402.71s, 6.60 s/epoch, 0.22 s/batch, ets 257.47s
#
# Test set: Average loss: 1.3979, Accuracy: 15/30 (50%)
#
# Epoch: 61
# Train Loss: 0.000014 Acc: 1.0000
# Elapsed 409.17s, 6.60 s/epoch, 0.22 s/batch, ets 250.78s
#
# Test set: Average loss: 1.4056, Accuracy: 15/30 (50%)
#
# Epoch: 62
# Train Loss: 0.000014 Acc: 1.0000
# Elapsed 416.11s, 6.60 s/epoch, 0.22 s/batch, ets 244.38s
#
# Test set: Average loss: 1.4086, Accuracy: 15/30 (50%)
#
# Epoch: 63
# Train Loss: 0.000013 Acc: 1.0000
# Elapsed 423.70s, 6.62 s/epoch, 0.22 s/batch, ets 238.33s
#
# Test set: Average loss: 1.4076, Accuracy: 15/30 (50%)
#
# Epoch: 64
# Train Loss: 0.000013 Acc: 1.0000
# Elapsed 430.66s, 6.63 s/epoch, 0.22 s/batch, ets 231.90s
#
# Test set: Average loss: 1.4170, Accuracy: 15/30 (50%)
#
# Epoch: 65
# Train Loss: 0.000012 Acc: 1.0000
# Elapsed 435.26s, 6.59 s/epoch, 0.22 s/batch, ets 224.22s
#
# Test set: Average loss: 1.4120, Accuracy: 15/30 (50%)
#
# Epoch: 66
# Train Loss: 0.000012 Acc: 1.0000
# Elapsed 441.30s, 6.59 s/epoch, 0.22 s/batch, ets 217.35s
#
# Test set: Average loss: 1.4233, Accuracy: 15/30 (50%)
#
# Epoch: 67
# Train Loss: 0.000011 Acc: 1.0000
# Elapsed 447.14s, 6.58 s/epoch, 0.22 s/batch, ets 210.42s
#
# Test set: Average loss: 1.4210, Accuracy: 15/30 (50%)
#
# Epoch: 68
# Train Loss: 0.000011 Acc: 1.0000
# Elapsed 452.87s, 6.56 s/epoch, 0.22 s/batch, ets 203.46s
#
# Test set: Average loss: 1.4287, Accuracy: 15/30 (50%)
#
# Epoch: 69
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 458.24s, 6.55 s/epoch, 0.22 s/batch, ets 196.39s
#
# Test set: Average loss: 1.4258, Accuracy: 15/30 (50%)
#
# Epoch: 70
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 464.91s, 6.55 s/epoch, 0.22 s/batch, ets 189.89s
#
# Test set: Average loss: 1.4311, Accuracy: 15/30 (50%)
#
# Epoch: 71
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 469.50s, 6.52 s/epoch, 0.22 s/batch, ets 182.58s
#
# Test set: Average loss: 1.4370, Accuracy: 15/30 (50%)
#
# Epoch: 72
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 474.32s, 6.50 s/epoch, 0.22 s/batch, ets 175.43s
#
# Test set: Average loss: 1.4388, Accuracy: 15/30 (50%)
#
# Epoch: 73
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 479.22s, 6.48 s/epoch, 0.22 s/batch, ets 168.37s
#
# Test set: Average loss: 1.4411, Accuracy: 15/30 (50%)
#
# Epoch: 74
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 484.17s, 6.46 s/epoch, 0.22 s/batch, ets 161.39s
#
# Test set: Average loss: 1.4465, Accuracy: 15/30 (50%)
#
# Epoch: 75
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 488.82s, 6.43 s/epoch, 0.21 s/batch, ets 154.37s
#
# Test set: Average loss: 1.4469, Accuracy: 15/30 (50%)
#
# Epoch: 76
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 494.06s, 6.42 s/epoch, 0.21 s/batch, ets 147.58s
#
# Test set: Average loss: 1.4520, Accuracy: 15/30 (50%)
#
# Epoch: 77
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 500.61s, 6.42 s/epoch, 0.21 s/batch, ets 141.20s
#
# Test set: Average loss: 1.4532, Accuracy: 15/30 (50%)
#
# Epoch: 78
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 505.35s, 6.40 s/epoch, 0.21 s/batch, ets 134.33s
#
# Test set: Average loss: 1.4520, Accuracy: 15/30 (50%)
#
# Epoch: 79
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 510.43s, 6.38 s/epoch, 0.21 s/batch, ets 127.61s
#
# Test set: Average loss: 1.4607, Accuracy: 15/30 (50%)
#
# Epoch: 80
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 516.40s, 6.38 s/epoch, 0.21 s/batch, ets 121.13s
#
# Test set: Average loss: 1.4653, Accuracy: 15/30 (50%)
#
# Epoch: 81
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 521.70s, 6.36 s/epoch, 0.21 s/batch, ets 114.52s
#
# Test set: Average loss: 1.4617, Accuracy: 15/30 (50%)
#
# Epoch: 82
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 530.65s, 6.39 s/epoch, 0.21 s/batch, ets 108.69s
#
# Test set: Average loss: 1.4652, Accuracy: 15/30 (50%)
#
# Epoch: 83
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 536.26s, 6.38 s/epoch, 0.21 s/batch, ets 102.15s
#
# Test set: Average loss: 1.4687, Accuracy: 15/30 (50%)
#
# Epoch: 84
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 540.66s, 6.36 s/epoch, 0.21 s/batch, ets 95.41s
#
# Test set: Average loss: 1.4745, Accuracy: 15/30 (50%)
#
# Epoch: 85
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 545.80s, 6.35 s/epoch, 0.21 s/batch, ets 88.85s
#
# Test set: Average loss: 1.4767, Accuracy: 15/30 (50%)
#
# Epoch: 86
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 550.78s, 6.33 s/epoch, 0.21 s/batch, ets 82.30s
#
# Test set: Average loss: 1.4799, Accuracy: 15/30 (50%)
#
# Epoch: 87
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 556.77s, 6.33 s/epoch, 0.21 s/batch, ets 75.92s
#
# Test set: Average loss: 1.4780, Accuracy: 15/30 (50%)
#
# Epoch: 88
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 561.55s, 6.31 s/epoch, 0.21 s/batch, ets 69.41s
#
# Test set: Average loss: 1.4858, Accuracy: 15/30 (50%)
#
# Epoch: 89
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 567.80s, 6.31 s/epoch, 0.21 s/batch, ets 63.09s
#
# Test set: Average loss: 1.4829, Accuracy: 15/30 (50%)
#
# Epoch: 90
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 573.87s, 6.31 s/epoch, 0.21 s/batch, ets 56.76s
#
# Test set: Average loss: 1.4842, Accuracy: 15/30 (50%)
#
# Epoch: 91
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 579.63s, 6.30 s/epoch, 0.21 s/batch, ets 50.40s
#
# Test set: Average loss: 1.4914, Accuracy: 16/30 (53%)
#
# Epoch: 92
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 584.51s, 6.29 s/epoch, 0.21 s/batch, ets 44.00s
#
# Test set: Average loss: 1.4921, Accuracy: 15/30 (50%)
#
# Epoch: 93
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 589.27s, 6.27 s/epoch, 0.21 s/batch, ets 37.61s
#
# Test set: Average loss: 1.4964, Accuracy: 16/30 (53%)
#
# Epoch: 94
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 595.02s, 6.26 s/epoch, 0.21 s/batch, ets 31.32s
#
# Test set: Average loss: 1.5030, Accuracy: 16/30 (53%)
#
# Epoch: 95
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 603.12s, 6.28 s/epoch, 0.21 s/batch, ets 25.13s
#
# Test set: Average loss: 1.5026, Accuracy: 16/30 (53%)
#
# Epoch: 96
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 611.86s, 6.31 s/epoch, 0.21 s/batch, ets 18.92s
#
# Test set: Average loss: 1.4989, Accuracy: 15/30 (50%)
#
# Epoch: 97
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 618.33s, 6.31 s/epoch, 0.21 s/batch, ets 12.62s
#
# Test set: Average loss: 1.5066, Accuracy: 16/30 (53%)
#
# Epoch: 98
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 624.16s, 6.30 s/epoch, 0.21 s/batch, ets 6.30s
#
# Test set: Average loss: 1.5075, Accuracy: 15/30 (50%)
#
# Epoch: 99
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 632.18s, 6.32 s/epoch, 0.21 s/batch, ets 0.00s
#
# Test set: Average loss: 1.5123, Accuracy: 16/30 (53%)
#
# Total time: 633.02, Best Loss: 0.823

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_loss_accuracy(train_loss=[train_loss],
#       2                    val_loss=[val_loss],
#       3                    train_acc=[train_acc],
#       4                    val_acc=[val_acc],
#       5                    colors=['blue'],
#       6                    loss_legend_loc='upper center',
#       7                    acc_legend_loc='upper left')
#
# NameError: name 'train_loss' is not defined

# %% [markdown]
# # <font style="color:blue">Step 5: Sample Prediction</font><a name="predictions"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    data = batch_input.to(device)
    
    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 3

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    print(interval)
    imgs = []
    inputs = []
    targets = []
    
    for i in range(batch_size):
        index = i * interval
        print(index)
        trans_input, target = test_dataset_trans.__getitem__(index)
        print(type(trans_input), trans_input.shape)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (17,11)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0} ({1:.2})    T: {2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]), fontsize=9)
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
# 200
# 0
# <class 'torch.Tensor'> torch.Size([3, 224, 224])
# 200
# <class 'torch.Tensor'> torch.Size([3, 224, 224])
# 400
# <class 'torch.Tensor'> torch.Size([3, 224, 224])

# %% [markdown]
# Ddespite training the network on a very small subset of data, you can see that the predictions are not that bad. This means that our model is ready for training.

# %% [markdown]
# # <font style="color:red">Step 6. Display Mistakes [15 points] </font><a name="display"></a>
#
# The above code displayed sample predictions. But correct predictions are of no use. So, write a similar function that will  display only the mistakes made by the network.
#
#
# **You have to display only 15 images.**

# %% [markdown]
# After completing the assignment, <font style="color:red">upload and submit the notebook on the portal</font> for checking and feedback.

# %%
import math
def get_sample_errors(model, data_root, mean, std, errors_per_class = 8):
    batch_size = 1

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    imgs = []
    targets = []
    preds = []    
    probs = []

    for j in [0,200,400]:
        error_count = 0
        for index in range(j,j+200) :
            trans_input, target = test_dataset_trans.__getitem__(index)
            img, _ = test_dataset.__getitem__(index)
            cls, prob = prediction(model, device, batch_input=torch.stack([trans_input]))
            if cls != target:
                # print(f" misclassification - j: {j} i:{i} pred: {cls} prob: {prob} target: {target}    - error count: {error_count}"  )
                imgs.append(img)
                targets.append(target)
                preds.append(cls[0])
                probs.append(prob[0])
                error_count +=1
            if error_count >= errors_per_class:
                break  # go to next class 
        # print(f" {error_count} errors founds for j = {j}")
        
    rows = math.ceil(errors_per_class/8) *3

    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (22, (rows)*3)
    fig = plt.figure()
    
    for i, target in enumerate(targets):
        plt.subplot(rows, 8, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('Pred:{0} ({1:.2})    True: {2}'.format(test_dataset.classes[preds[i]], 
                                                     probs[i], 
                                                     test_dataset.classes[targets[i]]), fontsize=9)
    fig.savefig('sample_prediction.png')
    plt.show()
    # return

# %%
train_config = TrainingConfiguration()
train_data_path = os.path.join(train_config.data_root, 'training')
mean, std = get_mean_std(train_data_path)
test_data_path = os.path.join(train_config.data_root, 'validation')

m = MyModel()
m = load_model(m)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %%
get_sample_errors(m, test_data_path, mean, std, errors_per_class=8)
