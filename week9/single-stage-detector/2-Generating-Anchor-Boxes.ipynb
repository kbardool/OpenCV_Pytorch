# %% [markdown]
# # <font style="color:blue">2. Generating Anchor Boxes</font>
#
# Our detector has 9 anchors for every feature map by default.
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/03/c3-w8-anchors.png' align='middle'>
#
# **What is feature map here?**
#
# Let's say `a` is an input image of dimension `256x256`, and it has two feature maps `b` (`8 x 8 feature map (grid)`) and `c` (`4 x 4 feature map (grid)`). One element of the feature map represents segments of pixels in the original image `a`.
#
#
#
# **Why 9?**
#
# To answer this question, let's take a look into DataEncoder class.
# We have 3 aspect ratios of sizes $1/2$, $1$ and $2$. For each size, there are `3` scales: $1, 2^{1/3}$ and $2^{2/3}$.
# These anchors of the appropriate sizes are generated for each of five feature maps we have.

# %%
from IPython.display import Code
import inspect
import math 
import torch 

from trainer.encoder import (
    DataEncoder,
    decode_boxes,
    encode_boxes,
    generate_anchors,
    generate_anchor_grid
)

# %%
Code(data=inspect.getsource(DataEncoder.__init__))
# Out:
#     def __init__(self, input_size):
#         self.input_size = input_size
#         self.anchor_areas = [8 * 8, 16 * 16., 32 * 32., 64 * 64., 128 * 128]  # p3 -> p7
#         self.aspect_ratios = [0.5, 1, 2]
#         self.scales = [1, pow(2, 1 / 3.), pow(2, 2 / 3.)]
#         num_fms = len(self.anchor_areas)
#         fm_sizes = [math.ceil(self.input_size[0] / pow(2., i + 3)) for i in range(num_fms)]
#         self.anchor_boxes = []
#         for i, fm_size in enumerate(fm_sizes):
#             anchors = generate_anchors(self.anchor_areas[i], self.aspect_ratios, self.scales)
#             anchor_grid = generate_anchor_grid(input_size, fm_size, anchors)
#             self.anchor_boxes.append(anchor_grid)
#         self.anchor_boxes = torch.cat(self.anchor_boxes, 0)
#         self.classes = ["__background__", "person"]

# %% [markdown]
# **Why have we chosen the following anchor area?**
# ```
# anchor_areas = [8 * 8, 16 * 16., 32 * 32., 64 * 64., 128 * 128]  # p3 -> p7
# ```
# The first anchor area is responsible for generating anchors for the first output layer of `FPN` and so on.
#
# ```
# 256/8 = 32
#
# 256/16 = 16
#    .
#    .
# 256/128 = 2
# ```
#
# **So, how do we generate them?**
#
# We first generate our 9 anchors, knowing which areas it should cover, using predefined ratios and scales.

# %%
print(Code(data=inspect.getsource(generate_anchors)))
# Out:
# def generate_anchors(anchor_area, aspect_ratios, scales):
#     anchors = []
#     for scale in scales:
#         for ratio in aspect_ratios:
#             h = round(math.sqrt(anchor_area) / ratio)
#             w = round(ratio * h)
#             x1 = (math.sqrt(anchor_area) - scale * w) * 0.5
#             y1 = (math.sqrt(anchor_area) - scale * h) * 0.5
#             x2 = (math.sqrt(anchor_area) + scale * w) * 0.5
#             y2 = (math.sqrt(anchor_area) + scale * h) * 0.5
#             anchors.append([x1, y1, x2, y2])
#     return torch.Tensor(anchors)

# %% [markdown]
# For each feature map we create a grid, that will allow us to densely put all of the possible boxes.

# %%
print(Code(data=inspect.getsource(generate_anchor_grid)))
# Out:
# def generate_anchor_grid(input_size, fm_size, anchors):
#     grid_size = input_size[0] / fm_size
#     x, y = torch.meshgrid(torch.arange(0, fm_size) * grid_size, torch.arange(0, fm_size) * grid_size)
#     anchors = anchors.view(-1, 1, 1, 4)
#     xyxy = torch.stack([x, y, x, y], 2).float()
#     boxes = (xyxy + anchors).permute(2, 1, 0, 3).contiguous().view(-1, 4)
#     boxes[:, 0::2] = boxes[:, 0::2].clamp(0, input_size[0])
#     boxes[:, 1::2] = boxes[:, 1::2].clamp(0, input_size[1])
#     return boxes

# %% [markdown]
# **Let's check the size of the anchor boxes. for input image size `3x256x256` and `3x300x300`.**

# %%
import math
import torch

# %%
class DataEncoder:
    def __init__(self, input_size):
        self.input_size = input_size
        self.anchor_areas = [8 * 8., 16 * 16., 32 * 32., 64 * 64., 128 * 128.]  # p3 -> p7
        self.aspect_ratios = [0.5, 1, 2]
        self.scales = [1, pow(2, 1 / 3.), pow(2, 2 / 3.)]
        num_fms = len(self.anchor_areas)
        fm_sizes = [math.ceil(self.input_size[0] / pow(2., i + 3))*1.0 for i in range(num_fms)]
        print(f" achor areas: {self.anchor_areas} ")
        print(f" nominator  : {[self.input_size[0]*1.0 for i in range(num_fms)]}")
        print(f" denominator: {[pow(2., i + 3) for i in range(num_fms)]}")
        print(f" fm_sizes   : {fm_sizes}")
        self.anchor_boxes = []
        for i, fm_size in enumerate(fm_sizes):
            print("------------------------------------")
            print(f" i: {i}   fm_size: {fm_size}")
            print("------------------------------------")
            print(f"\n Generate Anchors for anchor area {self.anchor_areas[i]}:")
            print("-----------------------------------------------------------\n")
            anchors = generate_anchors(self.anchor_areas[i], self.aspect_ratios, self.scales)
            print("\n Generate Anchor Grid:")
            print("---------------------\n")
            anchor_grid = generate_anchor_grid(input_size, fm_size, anchors)
            self.anchor_boxes.append(anchor_grid)
        self.anchor_boxes = torch.cat(self.anchor_boxes, 0)
        self.classes = ["__background__", "person"]

# %%
def generate_anchors(anchor_area, aspect_ratios, scales):
    anchors = []
    print(f" Anchor area: {anchor_area}  /  {math.sqrt(anchor_area)}")
    for scale in scales:
        for ratio in aspect_ratios:
            h = round(math.sqrt(anchor_area) / ratio)
            w = round(ratio * h)
            x1 = (math.sqrt(anchor_area) - scale * w) * 0.5
            y1 = (math.sqrt(anchor_area) - scale * h) * 0.5
            x2 = (math.sqrt(anchor_area) + scale * w) * 0.5
            y2 = (math.sqrt(anchor_area) + scale * h) * 0.5
            print(f"  scale: {scale:.3f}  ratio: {ratio:.3f}  h (sqrt(anchor area) / ratio): {h:4d}  w (ratio *h): {w:4d}  x1/y1: {x1:7.3f}/ {y1:7.3f}   x2/y2: {x2:7.3f}/{y2:7.3f}")
            anchors.append([x1, y1, x2, y2])
    return torch.Tensor(anchors)


def generate_anchor_grid(input_size, fm_size, anchors):
    grid_size = input_size[0] / fm_size
    print(f" fm_size   : {fm_size}")
    print(f" input_size: {input_size}")
    print(f" grid_size : {grid_size}  meshgrid: torch.arange(0, {fm_size}) * {grid_size}, torch.arange(0, {fm_size}) * {grid_size}")
    x, y = torch.meshgrid(torch.arange(0, fm_size) * grid_size, torch.arange(0, fm_size) * grid_size)
    print(f" anchors.shape:  {anchors.shape}          x1,y1,x2,y2:  {anchors[0]}")
    anchors = anchors.view(-1, 1, 1, 4)
    print(f" anchors.shape:  {anchors.shape}    x1,y1,x2,y2:  {anchors[0,:4]}")
    print(f" x.shape:  {x.shape}    {x[0,:4]}   {x[1,:4]}")
    print(f" y.shape:  {y.shape}    {y[0,:4]}   {y[1,:4]}")
    xyxy = torch.stack([x, y, x, y], 2).float()
    print(f" xyxy   : {xyxy.shape}  {xyxy[0,0]} {xyxy[0,1]}  {xyxy[1,1]} {xyxy[-1,-1]}  ")
    print(f" anchors.shape   :  {anchors.shape}    x1,y1,x2,y2:  {anchors[0,-1]}  ")
    _tmp = xyxy + anchors
    print(f" (xyxy + anchors):  { (_tmp).shape}    x1,y1,x2,y2:   {_tmp[0,-1]}    ")
    
    print(f"  permute: {(xyxy + anchors).permute(2, 1, 0, 3).shape}  contiguous: {(xyxy + anchors).permute(2, 1, 0, 3).contiguous().shape}  view(-1,4).shape: {(xyxy + anchors).permute(2, 1, 0, 3).contiguous().view(-1, 4).shape}      ") 
    boxes = (xyxy + anchors).permute(2, 1, 0, 3).contiguous().view(-1, 4)
    print(f" boxes.shape:  {boxes.shape}")
    
    boxes[:, 0::2] = boxes[:, 0::2].clamp(0, input_size[0])
    boxes[:, 1::2] = boxes[:, 1::2].clamp(0, input_size[1])
    return boxes

# %%
height_width = (256, 256)

data_encoder = DataEncoder(height_width)

print('anchor_boxes size: {}'.format(data_encoder.anchor_boxes.size()))

# %%
height_width = (300, 300)

data_encoder = DataEncoder(height_width)

print('anchor_boxes size: {}'.format(data_encoder.anchor_boxes.size()))
# Out:
#  0  300 / 8.0000 = 37.5000
#  1  300 / 16.0000 = 18.7500
#  2  300 / 32.0000 = 9.3750
#  3  300 / 64.0000 = 4.6875
#  4  300 / 128.0000 = 2.3438
#  fm_sizes: [38, 19, 10, 5, 3]
#
# ------------------------------------
#  i: 0   fm_size: 38
# ------------------------------------
#
# Generate Anchors:
# ------------------
#
#  Anchor area: 64  /  8.0
#   scale: 1.000  ratio: 0.500  h (sqrt(anchor area) / ratio):   16  w (ratio *h):    8  x1/y1:   0.000/  -4.000   x2/y2:   8.000/ 12.000
#   scale: 1.000  ratio: 1.000  h (sqrt(anchor area) / ratio):    8  w (ratio *h):    8  x1/y1:   0.000/   0.000   x2/y2:   8.000/  8.000
#   scale: 1.000  ratio: 2.000  h (sqrt(anchor area) / ratio):    4  w (ratio *h):    8  x1/y1:   0.000/   2.000   x2/y2:   8.000/  6.000
#   scale: 1.260  ratio: 0.500  h (sqrt(anchor area) / ratio):   16  w (ratio *h):    8  x1/y1:  -1.040/  -6.079   x2/y2:   9.040/ 14.079
#   scale: 1.260  ratio: 1.000  h (sqrt(anchor area) / ratio):    8  w (ratio *h):    8  x1/y1:  -1.040/  -1.040   x2/y2:   9.040/  9.040
#   scale: 1.260  ratio: 2.000  h (sqrt(anchor area) / ratio):    4  w (ratio *h):    8  x1/y1:  -1.040/   1.480   x2/y2:   9.040/  6.520
#   scale: 1.587  ratio: 0.500  h (sqrt(anchor area) / ratio):   16  w (ratio *h):    8  x1/y1:  -2.350/  -8.699   x2/y2:  10.350/ 16.699
#   scale: 1.587  ratio: 1.000  h (sqrt(anchor area) / ratio):    8  w (ratio *h):    8  x1/y1:  -2.350/  -2.350   x2/y2:  10.350/ 10.350
#   scale: 1.587  ratio: 2.000  h (sqrt(anchor area) / ratio):    4  w (ratio *h):    8  x1/y1:  -2.350/   0.825   x2/y2:  10.350/  7.175
#
# Generate Anchor Grid:
# ---------------------
#
#  fm_size   : 38
#  input_size: (300, 300)
#  grid_size : 7.894736842105263  meshgrid: torch.arange(0, 38) * 7.894736842105263, torch.arange(0, 38) * 7.894736842105263
#  anchors.shape:  torch.Size([9, 4])          x1,y1,x2,y2:  tensor([ 0., -4.,  8., 12.])
#  anchors.shape:  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[[ 0., -4.,  8., 12.]]])
#  x.shape:  torch.Size([38, 38])    tensor([0., 0., 0., 0.])   tensor([7.8947, 7.8947, 7.8947, 7.8947])
#  y.shape:  torch.Size([38, 38])    tensor([ 0.0000,  7.8947, 15.7895, 23.6842])   tensor([ 0.0000,  7.8947, 15.7895, 23.6842])
#  xyxy   : torch.Size([38, 38, 4])  tensor([0., 0., 0., 0.]) tensor([0.0000, 7.8947, 0.0000, 7.8947])  tensor([7.8947, 7.8947, 7.8947, 7.8947]) tensor([292.1053, 292.1053, 292.1053, 292.1053])
#  anchors.shape   :  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[ 0., -4.,  8., 12.]])
#  (xyxy + anchors):  torch.Size([9, 38, 38, 4])    x1,y1,x2,y2:   tensor([[292.1053,  -4.0000, 300.1053,  12.0000],
#         [292.1053,   3.8947, 300.1053,  19.8947],
#         [292.1053,  11.7895, 300.1053,  27.7895],
#         [292.1053,  19.6842, 300.1053,  35.6842],
#         [292.1053,  27.5789, 300.1053,  43.5789],
#         [292.1053,  35.4737, 300.1053,  51.4737],
#         [292.1053,  43.3684, 300.1053,  59.3684],
#         [292.1053,  51.2632, 300.1053,  67.2632],
#         [292.1053,  59.1579, 300.1053,  75.1579],
#         [292.1053,  67.0526, 300.1053,  83.0526],
#         [292.1053,  74.9474, 300.1053,  90.9474],
#         [292.1053,  82.8421, 300.1053,  98.8421],
#         [292.1053,  90.7368, 300.1053, 106.7368],
#         [292.1053,  98.6316, 300.1053, 114.6316],
#         [292.1053, 106.5263, 300.1053, 122.5263],
#         [292.1053, 114.4211, 300.1053, 130.4211],
#         [292.1053, 122.3158, 300.1053, 138.3158],
#         [292.1053, 130.2105, 300.1053, 146.2105],
#         [292.1053, 138.1053, 300.1053, 154.1053],
#         [292.1053, 146.0000, 300.1053, 162.0000],
#         [292.1053, 153.8947, 300.1053, 169.8947],
#         [292.1053, 161.7895, 300.1053, 177.7895],
#         [292.1053, 169.6842, 300.1053, 185.6842],
#         [292.1053, 177.5789, 300.1053, 193.5789],
#         [292.1053, 185.4737, 300.1053, 201.4737],
#         [292.1053, 193.3684, 300.1053, 209.3684],
#         [292.1053, 201.2632, 300.1053, 217.2632],
#         [292.1053, 209.1579, 300.1053, 225.1579],
#         [292.1053, 217.0526, 300.1053, 233.0526],
#         [292.1053, 224.9474, 300.1053, 240.9474],
#         [292.1053, 232.8421, 300.1053, 248.8421],
#         [292.1053, 240.7368, 300.1053, 256.7368],
#         [292.1053, 248.6316, 300.1053, 264.6316],
#         [292.1053, 256.5263, 300.1053, 272.5263],
#         [292.1053, 264.4211, 300.1053, 280.4211],
#         [292.1053, 272.3158, 300.1053, 288.3158],
#         [292.1053, 280.2105, 300.1053, 296.2105],
#         [292.1053, 288.1053, 300.1053, 304.1053]])
#   permute: torch.Size([38, 38, 9, 4])  contiguous: torch.Size([38, 38, 9, 4])  view(-1,4).shape: torch.Size([12996, 4])
#  boxes.shape:  torch.Size([12996, 4])
# ------------------------------------
#  i: 1   fm_size: 19
# ------------------------------------
#
# Generate Anchors:
# ------------------
#
#  Anchor area: 256.0  /  16.0
#   scale: 1.000  ratio: 0.500  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   16  x1/y1:   0.000/  -8.000   x2/y2:  16.000/ 24.000
#   scale: 1.000  ratio: 1.000  h (sqrt(anchor area) / ratio):   16  w (ratio *h):   16  x1/y1:   0.000/   0.000   x2/y2:  16.000/ 16.000
#   scale: 1.000  ratio: 2.000  h (sqrt(anchor area) / ratio):    8  w (ratio *h):   16  x1/y1:   0.000/   4.000   x2/y2:  16.000/ 12.000
#   scale: 1.260  ratio: 0.500  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   16  x1/y1:  -2.079/ -12.159   x2/y2:  18.079/ 28.159
#   scale: 1.260  ratio: 1.000  h (sqrt(anchor area) / ratio):   16  w (ratio *h):   16  x1/y1:  -2.079/  -2.079   x2/y2:  18.079/ 18.079
#   scale: 1.260  ratio: 2.000  h (sqrt(anchor area) / ratio):    8  w (ratio *h):   16  x1/y1:  -2.079/   2.960   x2/y2:  18.079/ 13.040
#   scale: 1.587  ratio: 0.500  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   16  x1/y1:  -4.699/ -17.398   x2/y2:  20.699/ 33.398
#   scale: 1.587  ratio: 1.000  h (sqrt(anchor area) / ratio):   16  w (ratio *h):   16  x1/y1:  -4.699/  -4.699   x2/y2:  20.699/ 20.699
#   scale: 1.587  ratio: 2.000  h (sqrt(anchor area) / ratio):    8  w (ratio *h):   16  x1/y1:  -4.699/   1.650   x2/y2:  20.699/ 14.350
#
# Generate Anchor Grid:
# ---------------------
#
#  fm_size   : 19
#  input_size: (300, 300)
#  grid_size : 15.789473684210526  meshgrid: torch.arange(0, 19) * 15.789473684210526, torch.arange(0, 19) * 15.789473684210526
#  anchors.shape:  torch.Size([9, 4])          x1,y1,x2,y2:  tensor([ 0., -8., 16., 24.])
#  anchors.shape:  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[[ 0., -8., 16., 24.]]])
#  x.shape:  torch.Size([19, 19])    tensor([0., 0., 0., 0.])   tensor([15.7895, 15.7895, 15.7895, 15.7895])
#  y.shape:  torch.Size([19, 19])    tensor([ 0.0000, 15.7895, 31.5789, 47.3684])   tensor([ 0.0000, 15.7895, 31.5789, 47.3684])
#  xyxy   : torch.Size([19, 19, 4])  tensor([0., 0., 0., 0.]) tensor([ 0.0000, 15.7895,  0.0000, 15.7895])  tensor([15.7895, 15.7895, 15.7895, 15.7895]) tensor([284.2105, 284.2105, 284.2105, 284.2105])
#  anchors.shape   :  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[ 0., -8., 16., 24.]])
#  (xyxy + anchors):  torch.Size([9, 19, 19, 4])    x1,y1,x2,y2:   tensor([[284.2105,  -8.0000, 300.2105,  24.0000],
#         [284.2105,   7.7895, 300.2105,  39.7895],
#         [284.2105,  23.5789, 300.2105,  55.5789],
#         [284.2105,  39.3684, 300.2105,  71.3684],
#         [284.2105,  55.1579, 300.2105,  87.1579],
#         [284.2105,  70.9474, 300.2105, 102.9474],
#         [284.2105,  86.7368, 300.2105, 118.7368],
#         [284.2105, 102.5263, 300.2105, 134.5263],
#         [284.2105, 118.3158, 300.2105, 150.3158],
#         [284.2105, 134.1053, 300.2105, 166.1053],
#         [284.2105, 149.8947, 300.2105, 181.8947],
#         [284.2105, 165.6842, 300.2105, 197.6842],
#         [284.2105, 181.4737, 300.2105, 213.4737],
#         [284.2105, 197.2632, 300.2105, 229.2632],
#         [284.2105, 213.0526, 300.2105, 245.0526],
#         [284.2105, 228.8421, 300.2105, 260.8421],
#         [284.2105, 244.6316, 300.2105, 276.6316],
#         [284.2105, 260.4211, 300.2105, 292.4211],
#         [284.2105, 276.2105, 300.2105, 308.2105]])
#   permute: torch.Size([19, 19, 9, 4])  contiguous: torch.Size([19, 19, 9, 4])  view(-1,4).shape: torch.Size([3249, 4])
#  boxes.shape:  torch.Size([3249, 4])
# ------------------------------------
#  i: 2   fm_size: 10
# ------------------------------------
#
# Generate Anchors:
# ------------------
#
#  Anchor area: 1024.0  /  32.0
#   scale: 1.000  ratio: 0.500  h (sqrt(anchor area) / ratio):   64  w (ratio *h):   32  x1/y1:   0.000/ -16.000   x2/y2:  32.000/ 48.000
#   scale: 1.000  ratio: 1.000  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   32  x1/y1:   0.000/   0.000   x2/y2:  32.000/ 32.000
#   scale: 1.000  ratio: 2.000  h (sqrt(anchor area) / ratio):   16  w (ratio *h):   32  x1/y1:   0.000/   8.000   x2/y2:  32.000/ 24.000
#   scale: 1.260  ratio: 0.500  h (sqrt(anchor area) / ratio):   64  w (ratio *h):   32  x1/y1:  -4.159/ -24.317   x2/y2:  36.159/ 56.317
#   scale: 1.260  ratio: 1.000  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   32  x1/y1:  -4.159/  -4.159   x2/y2:  36.159/ 36.159
#   scale: 1.260  ratio: 2.000  h (sqrt(anchor area) / ratio):   16  w (ratio *h):   32  x1/y1:  -4.159/   5.921   x2/y2:  36.159/ 26.079
#   scale: 1.587  ratio: 0.500  h (sqrt(anchor area) / ratio):   64  w (ratio *h):   32  x1/y1:  -9.398/ -34.797   x2/y2:  41.398/ 66.797
#   scale: 1.587  ratio: 1.000  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   32  x1/y1:  -9.398/  -9.398   x2/y2:  41.398/ 41.398
#   scale: 1.587  ratio: 2.000  h (sqrt(anchor area) / ratio):   16  w (ratio *h):   32  x1/y1:  -9.398/   3.301   x2/y2:  41.398/ 28.699
#
# Generate Anchor Grid:
# ---------------------
#
#  fm_size   : 10
#  input_size: (300, 300)
#  grid_size : 30.0  meshgrid: torch.arange(0, 10) * 30.0, torch.arange(0, 10) * 30.0
#  anchors.shape:  torch.Size([9, 4])          x1,y1,x2,y2:  tensor([  0., -16.,  32.,  48.])
#  anchors.shape:  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[[  0., -16.,  32.,  48.]]])
#  x.shape:  torch.Size([10, 10])    tensor([0., 0., 0., 0.])   tensor([30., 30., 30., 30.])
#  y.shape:  torch.Size([10, 10])    tensor([ 0., 30., 60., 90.])   tensor([ 0., 30., 60., 90.])
#  xyxy   : torch.Size([10, 10, 4])  tensor([0., 0., 0., 0.]) tensor([ 0., 30.,  0., 30.])  tensor([30., 30., 30., 30.]) tensor([270., 270., 270., 270.])
#  anchors.shape   :  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[  0., -16.,  32.,  48.]])
#  (xyxy + anchors):  torch.Size([9, 10, 10, 4])    x1,y1,x2,y2:   tensor([[270., -16., 302.,  48.],
#         [270.,  14., 302.,  78.],
#         [270.,  44., 302., 108.],
#         [270.,  74., 302., 138.],
#         [270., 104., 302., 168.],
#         [270., 134., 302., 198.],
#         [270., 164., 302., 228.],
#         [270., 194., 302., 258.],
#         [270., 224., 302., 288.],
#         [270., 254., 302., 318.]])
#   permute: torch.Size([10, 10, 9, 4])  contiguous: torch.Size([10, 10, 9, 4])  view(-1,4).shape: torch.Size([900, 4])
#  boxes.shape:  torch.Size([900, 4])
# ------------------------------------
#  i: 3   fm_size: 5
# ------------------------------------
#
# Generate Anchors:
# ------------------
#
#  Anchor area: 4096.0  /  64.0
#   scale: 1.000  ratio: 0.500  h (sqrt(anchor area) / ratio):  128  w (ratio *h):   64  x1/y1:   0.000/ -32.000   x2/y2:  64.000/ 96.000
#   scale: 1.000  ratio: 1.000  h (sqrt(anchor area) / ratio):   64  w (ratio *h):   64  x1/y1:   0.000/   0.000   x2/y2:  64.000/ 64.000
#   scale: 1.000  ratio: 2.000  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   64  x1/y1:   0.000/  16.000   x2/y2:  64.000/ 48.000
#   scale: 1.260  ratio: 0.500  h (sqrt(anchor area) / ratio):  128  w (ratio *h):   64  x1/y1:  -8.317/ -48.635   x2/y2:  72.317/112.635
#   scale: 1.260  ratio: 1.000  h (sqrt(anchor area) / ratio):   64  w (ratio *h):   64  x1/y1:  -8.317/  -8.317   x2/y2:  72.317/ 72.317
#   scale: 1.260  ratio: 2.000  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   64  x1/y1:  -8.317/  11.841   x2/y2:  72.317/ 52.159
#   scale: 1.587  ratio: 0.500  h (sqrt(anchor area) / ratio):  128  w (ratio *h):   64  x1/y1: -18.797/ -69.594   x2/y2:  82.797/133.594
#   scale: 1.587  ratio: 1.000  h (sqrt(anchor area) / ratio):   64  w (ratio *h):   64  x1/y1: -18.797/ -18.797   x2/y2:  82.797/ 82.797
#   scale: 1.587  ratio: 2.000  h (sqrt(anchor area) / ratio):   32  w (ratio *h):   64  x1/y1: -18.797/   6.602   x2/y2:  82.797/ 57.398
#
# Generate Anchor Grid:
# ---------------------
#
#  fm_size   : 5
#  input_size: (300, 300)
#  grid_size : 60.0  meshgrid: torch.arange(0, 5) * 60.0, torch.arange(0, 5) * 60.0
#  anchors.shape:  torch.Size([9, 4])          x1,y1,x2,y2:  tensor([  0., -32.,  64.,  96.])
#  anchors.shape:  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[[  0., -32.,  64.,  96.]]])
#  x.shape:  torch.Size([5, 5])    tensor([0., 0., 0., 0.])   tensor([60., 60., 60., 60.])
#  y.shape:  torch.Size([5, 5])    tensor([  0.,  60., 120., 180.])   tensor([  0.,  60., 120., 180.])
#  xyxy   : torch.Size([5, 5, 4])  tensor([0., 0., 0., 0.]) tensor([ 0., 60.,  0., 60.])  tensor([60., 60., 60., 60.]) tensor([240., 240., 240., 240.])
#  anchors.shape   :  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[  0., -32.,  64.,  96.]])
#  (xyxy + anchors):  torch.Size([9, 5, 5, 4])    x1,y1,x2,y2:   tensor([[240., -32., 304.,  96.],
#         [240.,  28., 304., 156.],
#         [240.,  88., 304., 216.],
#         [240., 148., 304., 276.],
#         [240., 208., 304., 336.]])
#   permute: torch.Size([5, 5, 9, 4])  contiguous: torch.Size([5, 5, 9, 4])  view(-1,4).shape: torch.Size([225, 4])
#  boxes.shape:  torch.Size([225, 4])
# ------------------------------------
#  i: 4   fm_size: 3
# ------------------------------------
#
# Generate Anchors:
# ------------------
#
#  Anchor area: 16384  /  128.0
#   scale: 1.000  ratio: 0.500  h (sqrt(anchor area) / ratio):  256  w (ratio *h):  128  x1/y1:   0.000/ -64.000   x2/y2: 128.000/192.000
#   scale: 1.000  ratio: 1.000  h (sqrt(anchor area) / ratio):  128  w (ratio *h):  128  x1/y1:   0.000/   0.000   x2/y2: 128.000/128.000
#   scale: 1.000  ratio: 2.000  h (sqrt(anchor area) / ratio):   64  w (ratio *h):  128  x1/y1:   0.000/  32.000   x2/y2: 128.000/ 96.000
#   scale: 1.260  ratio: 0.500  h (sqrt(anchor area) / ratio):  256  w (ratio *h):  128  x1/y1: -16.635/ -97.270   x2/y2: 144.635/225.270
#   scale: 1.260  ratio: 1.000  h (sqrt(anchor area) / ratio):  128  w (ratio *h):  128  x1/y1: -16.635/ -16.635   x2/y2: 144.635/144.635
#   scale: 1.260  ratio: 2.000  h (sqrt(anchor area) / ratio):   64  w (ratio *h):  128  x1/y1: -16.635/  23.683   x2/y2: 144.635/104.317
#   scale: 1.587  ratio: 0.500  h (sqrt(anchor area) / ratio):  256  w (ratio *h):  128  x1/y1: -37.594/ -139.187   x2/y2: 165.594/267.187
#   scale: 1.587  ratio: 1.000  h (sqrt(anchor area) / ratio):  128  w (ratio *h):  128  x1/y1: -37.594/ -37.594   x2/y2: 165.594/165.594
#   scale: 1.587  ratio: 2.000  h (sqrt(anchor area) / ratio):   64  w (ratio *h):  128  x1/y1: -37.594/  13.203   x2/y2: 165.594/114.797
#
# Generate Anchor Grid:
# ---------------------
#
#  fm_size   : 3
#  input_size: (300, 300)
#  grid_size : 100.0  meshgrid: torch.arange(0, 3) * 100.0, torch.arange(0, 3) * 100.0
#  anchors.shape:  torch.Size([9, 4])          x1,y1,x2,y2:  tensor([  0., -64., 128., 192.])
#  anchors.shape:  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[[  0., -64., 128., 192.]]])
#  x.shape:  torch.Size([3, 3])    tensor([0., 0., 0.])   tensor([100., 100., 100.])
#  y.shape:  torch.Size([3, 3])    tensor([  0., 100., 200.])   tensor([  0., 100., 200.])
#  xyxy   : torch.Size([3, 3, 4])  tensor([0., 0., 0., 0.]) tensor([  0., 100.,   0., 100.])  tensor([100., 100., 100., 100.]) tensor([200., 200., 200., 200.])
#  anchors.shape   :  torch.Size([9, 1, 1, 4])    x1,y1,x2,y2:  tensor([[  0., -64., 128., 192.]])
#  (xyxy + anchors):  torch.Size([9, 3, 3, 4])    x1,y1,x2,y2:   tensor([[200., -64., 328., 192.],
#         [200.,  36., 328., 292.],
#         [200., 136., 328., 392.]])
#   permute: torch.Size([3, 3, 9, 4])  contiguous: torch.Size([3, 3, 9, 4])  view(-1,4).shape: torch.Size([81, 4])
#  boxes.shape:  torch.Size([81, 4])
# anchor_boxes size: torch.Size([17451, 4])

# %% [markdown]
# **Let's compare anchor boxes size to detector network output size:**
#
# <div>
#     <table>
#         <tr><td><h3>Image input size</h3></td> <td><h3>Anchor boxes size</h3></td> <td><h3>Detector Network output size</h3></td> </tr>
#         <tr><td><h3>(256, 256)</h3></td> <td><h3>[12276, 4]</h3></td> <td><h3>[batch_size, 12276, 4]</h3></td> </tr>
#         <tr><td><h3>(300, 300)</h3></td> <td><h3>[17451, 4]</h3></td> <td><h3>[batch_size, 17451, 4]</h3></td> </tr>
#     </table>
# </div>
#
# Basically, we want to encode our location target, such that the size location target becomes equal to the size of anchor boxes.

# %%
import math
import torch

# %%
class DataEncoder:
         
    def __init__(self, input_size):
        self.input_size = input_size
        self.anchor_areas = [8 * 8, 16 * 16., 32 * 32., 64 * 64., 128 * 128]  # p3 -> p7
        self.aspect_ratios = [0.5, 1, 2]
        self.scales = [1, pow(2, 1 / 3.), pow(2, 2 / 3.)]
        num_fms = len(self.anchor_areas)
        for i in range(num_fms):
            print(f" {i}  {self.input_size[0]} / {pow(2.,i+3):.4f} = {self.input_size[0] / pow(2., i + 3):.4f}")
        fm_sizes = [math.ceil(self.input_size[0] / pow(2., i + 3)) for i in range(num_fms)]
        print(f" fm_sizes: {fm_sizes} \n")
        self.anchor_boxes = []
        
        for i, fm_size in enumerate(fm_sizes):
            print("------------------------------------")
            print(f" i: {i}   fm_size: {fm_size}")
            print("------------------------------------")
            print("\nGenerate Anchors:")
            print("------------------\n")
            anchors = generate_anchors(self.anchor_areas[i], self.aspect_ratios, self.scales)
            print("\nGenerate Anchor Grid:")
            print("---------------------\n")
            anchor_grid = generate_anchor_grid(input_size, fm_size, anchors)
            self.anchor_boxes.append(anchor_grid)
        self.anchor_boxes = torch.cat(self.anchor_boxes, 0)
        self.classes = ["__background__", "person"]

    def encode(self, boxes, classes):
        iou = compute_iou(boxes, self.anchor_boxes)
        iou, ids = iou.max(1)
        loc_targets = encode_boxes(boxes[ids], self.anchor_boxes)
        cls_targets = classes[ids]
        cls_targets[iou < 0.5] = -1
        cls_targets[iou < 0.4] = 0

        return loc_targets, cls_targets

    def decode(self, loc_pred, cls_pred, cls_threshold=0.7, nms_threshold=0.3):
        all_boxes = [[] for _ in range(len(loc_pred))]  # batch_size

        for sample_id, (boxes, scores) in enumerate(zip(loc_pred, cls_pred)):
            boxes = decode_boxes(boxes, self.anchor_boxes)

            conf = scores.softmax(dim=1)
            sample_boxes = [[] for _ in range(len(self.classes))]
            for class_idx, class_name in enumerate(self.classes):
                if class_name == '__background__':
                    continue
                class_conf = conf[:, class_idx]
                ids = (class_conf > cls_threshold).nonzero().squeeze()
                ids = [ids.tolist()]
                keep = compute_nms(boxes[ids], class_conf[ids], threshold=nms_threshold)

                conf_out, top_ids = torch.sort(class_conf[ids][keep], dim=0, descending=True)
                boxes_out = boxes[ids][keep][top_ids]

                boxes_out = boxes_out.cpu().numpy()
                conf_out = conf_out.cpu().numpy()

                c_dets = np.hstack((boxes_out, conf_out[:, np.newaxis])).astype(np.float32, copy=False)
                c_dets = c_dets[c_dets[:, 4].argsort()]
                sample_boxes[class_idx] = c_dets

            all_boxes[sample_id] = sample_boxes

        return all_boxes

    def get_num_anchors(self):
        return len(self.aspect_ratios) * len(self.scales)

# %%
# Code(data=inspect.getsource(DataEncoder))
