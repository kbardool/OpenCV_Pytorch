# %%
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("slothkong/10-monkey-species")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 547M/547M [00:14<00:00, 40.6MB/s]
# Extracting files...
# Path to dataset files: /home/kbardool/.cache/kagglehub/datasets/slothkong/10-monkey-species/versions/2

# %%
# !dir /home/kbardool/.cache/kagglehub/datasets/slothkong/10-monkey-species/versions/2/
# Out:
# monkey_labels.txt  training  validation

# %%
# !tree /home/kbardool/.cache/kagglehub/datasets/slothkong/10-monkey-species/versions/2
